# %% [markdown]
# # Elementos da versão
#
# Antes mesmo de falar do projeto, ao longo do desenvolvimento, vamos explicitando qual o objetivo de cada versão de trabalho do arquivo principal.
#
# Tivemos problemas de análise dos resultados da v1. Os dados de mortalidade de doenças evitáveis em 2022 por município estão muito altos e fora do padrão esperado.
#
# O objetivo desta v.2 é criar um dataset diferente, mais básico que permite que aprendamos com os erros e acertos, verificando melhor cada etapa de trabalho.
#
# O dataset desta v.2 deverá ter as seguintes características:
#
# * setting: Brasil [poderemos encontrar um sufixo a Brasil que permita a sua subclassificação e carga deste dataset junto a outros]
# * dimension: CID evitáveis
# * subgroup: municípios
# * estimate: mort-avoid por município
# * setting-average: mort-avoid por Brasil

# %% [markdown]
# # Projeto de Análise de Desigualdade em Saúde no modelo HEAT/OMS
# ## Bloco 2025/1 = análise do sistema de mortalidade do SUS com agregação por unidades federativas

# %% [markdown]
# #### Aspectos gerais e participantes

# %% [markdown]
# Projeto Desenvolvido em parceria da MS/SECTICS/DESID com a Organização Mundial de Saúde
#
# Elaborado em linguagem Python, utilizando a biblioteca pysus para acesso ao SIM (Sistema de Informações de Mortalidade do SUS)
#
# Coordenador-geral:
#
# Coordenadores:
#
# Cientista de dados: Marcos Mesquita
#
# Outros participantes:
#
# Data: 06/12/2024

# %% [markdown]
# #### Objetivos

# %% [markdown]
# O principal objetivo desse projeto é realizar a avaliação de desigualdade na saúde no Brasil com ênfase para a dimensão de unidades subnacionais, estados e municípios brasileiros, a partir da aplicação do modelo do HEAT, tendo como objetivos específicos:
#
# - Apresentar indicadores de saúde no Brasil desagregados por subunidades nacionais em uma visualização interativa a partir do modelo do HEAT Plus;
# - Oferecer um repositório comum e atualizado com dados de desigualdade da saúde no Brasil desagregados por estados e municípios em um modelo sob reconhecimento internacional;
# - Permitir exploração e acesso dos dados e da metodologia para outros tipos de análises.

# %% [markdown]
# # Etapa 1 - Definição do Bloco
#
# O projeto ocorrerá em blocos sucessivos, nos quais serão definidos o problema e os indicadores a serem analisados.

# %% [markdown]
# ### Definição do problema do bloco

# %% [markdown]
#  H0 - as unidades federativa são variáveis determinantes para mortalidade no país

# %% [markdown]
# ### Escopo do Bloco 1

# %% [markdown]
# * indicador: mortalidade (número de mortes por população, dados de morte do SIM/SUS e dados populacionais pelo Censos de 2010 e 2022)
# * localização: todo o Brasil, com agregação de mortalidade por Estados e Municípios
# * período: 2010 e 2022
# * doenças: “doenças evitáveis” conforme definido pelo OCDE
# * outros critérios de filtro: até 74 anos de idade (em razão da aplicação do critério de "doenças evitáveis")

# %% [markdown]
# # Etapa 2 - Análise primária dos dados por bloco

# %% [markdown]
# ## Aspectos teóricos e técnicos das fontes

# %% [markdown]
# #### Aspectos técnicos - ambiente, linguagem e ferramentas principais
#
# A análise será feita utilizando a linguagem Python e a biblioteca Pysus que permite acesso às principais bases do SUS de forma direta.
# O Pysus exige um ambiente linux para execução de alguns comandos o que foi possível, mesmo em uma máquina Windows, a partir do WSL do Windows.
# Foi criado um ambiente em WSL e o conjunto da extração, tratamento e análise dos dados foi realizado no formato Notebook em um editor VSCode, dentro de um Dev Container: Default Linux Universal.
#
#
# #### Morte e mortalidade no HEAT
#
# Para entendermos como o HEAT trata a mortalidade, fizemos uma busca de indicadores de mortalidade no WHO Health Inequality Data Repository.
#
# O repositório traz dados e metadados de todos os indicadores utilizados pelo HEAT.
# Apresenta um total de 3915 indicadores, distribuídos entre 14 seções.
#
# Foi feita uma revisão geral dos indicadores relacionados à mortalidade, que depois foi refinada pela busca das seguintes palavras : “death”, “mortality”, “fatal”, ‘fatality” ,“Probability of dying”, “suicide”. E foram encontrados 388 indicadores que trazem uma destas expressões na sua descrição.
#
#
# #### SIM (Sistema de Informações de Mortalidade do SUS)
#
# A mortalidade e os indicadores de morte serão buscados no SIM (Sistema de Informações de Mortalidade do SUS).
# O SIM disponibiliza dados de mortes no Brasil desde 1996 por ocorrências, gerido pelo Departamento de Análise de Situação de Saúde, da Secretaria de Vigilância em Saúde do Ministério da Saúde, em conjunto com as Secretarias Estaduais e Municipais de Saúde. Estas últimas responsáveis efetivamente pela coleta dos dados.
#
# O SIM traz informações do indivíduo, como sexo, idade, localidade e causas da morte, classificadas de acordo com o CID (Classificação Internacional de Doenças e Problemas Relacionadas à Saúde).
#
#
# #### CID (Classificação Internacional de Doenças e Problemas Relacionadas à Saúde)
#
# Com o intuito de padronizar a nomenclatura de patologias e com abrangência para todo o mundo, foi elaborado pela Organização Mundial da Saúde (OMS) uma  classificação internacional de doenças, a CID (Classificação Internacional de Doenças e Problemas Relacionadas à Saúde).
#
# A Classificação é atualizada periodicamente. A versão mais atual é a CID11, publicada em janeiro de 2022.
#
# No entanto, por se tratar de revisão que traz impactos nos registros e que exige considerável atualização das ferramentas de captura das informações, o SIM utiliza versões anteriores da CID.
# - CID9 - dados até 1995
# - CID10 - a partir de 1996 até a data atual
#
# Em razão do recorte temporal dos dados, de 1998 a 2022, iremos utilizar somente a CID10.
# A CID10 é organizada em 22 capítulos e possui, além da classificação de doenças, descrição de códigos que permitem identificar sinais, sintomas, queixas, causas externas e circunstâncias sociais.
#
#
# #### CID de doenças evitáveis
#
# Como elemento do escopo deste trabalho iremos tratar de doenças evitáveis.
#
# O Brasil, a partir da Secretaria de Vigilância em Saúde apresenta uma classificação de doenças evitáveis.
#
# Lista de causas evitáveis pode ser encontrada nos links: http://tabnet.datasus.gov.br/cgi/sim/Obitos_Evitaveis_0_a_4_anos.pdf
#
#
#
#
# #### População (Censo)
#
#
# Os dados de população são os do Censo, acessados pelo site do IBGE, https://sidra.ibge.gov.br/Tabela/9606

# %% [markdown]
# ### Instalação e importação de bibliotecas

# %% [markdown]
# #### Instalação de bibliotecas

# %%
# Costuma ser exigida a instalação destas bibliotecas no primeiro acesso ao Pysus
# !apt-get update  
# !apt-get install libffi-dev  # Install libffi-dev
# !pip install --upgrade pip  # Ensure pip is up to date
# !pip install pysus # Exa
# !pip install gdown
# !pip install pylance
# !pip install tabulate

# %% [markdown]
# #### Importação de bibliotecas

# %%
# importar biblioteca básicas para manipulação de dados
import pandas as pd
import numpy as np
import os
import sidrapy
import requests # para carga de endereços web - api
import gdown
import openpyxl
from tabulate import tabulate

# %%
# importar bibliotecas para carga dos dados
import pysus
# import pylance
from pysus import SIM
from pysus.online_data.SIM import download
from pysus.preprocessing.decoders import translate_variables_SIM
from pysus.preprocessing.SIM import group_and_count, redistribute_missing, redistribute_cid_chapter
from pysus.online_data.SIM import get_CID9_table, get_CID10_table, get_municipios, get_ocupations
from ftplib import FTP
from pathlib import Path

# %%
# Para organizar resultados, gerar prints em amarelo

def print_y(text):
  """Imprime o texto fornecido na cor amarela.

  Args:
    text: O texto a ser impresso.
  """
  print(f"\033[33m ==> {text}\033[0m")

# Exemplo de uso:
print_y("Este texto será impresso em amarelo!")
print("Este em normal!")
# Out:
#  ==> Este texto será impresso em amarelo!
# Este em normal!

# %% [markdown]
# #### Diretórios - configuração

# %%
# Definir diretório padrão para pysus
pysus.online_data.SIM.CACHEPATH="./downloads_sim_original"
# Definir pasta para download de arquivos csv e parquet
import os 

# Define diretório para armazenar arquivos do sim (carregados por pysus) quando o SIM.CACHEPATH não funcionar
os.makedirs('downloads_sim_original', exist_ok=True)  
downloads_sim = "downloads_sim_original"

# Define diretório para armazenar outros arquivos
os.makedirs('downloads_outros_v2', exist_ok=True)  

# Define diretório para armazenar arquivos trabalhados
os.makedirs('files_clean_v2', exist_ok=True) 


# Define diretório para exportar arquivos finais ou de relatórios
os.makedirs('exportar_v2', exist_ok=True)

# %% [markdown]
# #### Acesso ao SIM

# %%
sim = SIM().load() # Loads the files from DATASUS

# %%
sim.paths
# Out:
# (/dissemin/publicos/SIM/CID10/DORES, /dissemin/publicos/SIM/CID9/DORES)

# %%
sim.groups
# Out:
# {'CID10': 'DO', 'CID9': 'DOR'}

# %% [markdown]
# ## Arquivo principal - DO
#
# DO - Declaração de Óbito, conforme acessado no SIM

# %% [markdown]
# #### Carga SIM principal

# %%
# Carrega os dados do SIM para o ano de 2010
# Definição de variáveis
grupo = "CID10" # Agrupamento por CID10
uf = "" # A sigla BR carrega dados de todos as unidades federativas
ano = [2010] # Anos do escopo, 2010 e 2022
local = downloads_sim # Local para armazenar os arquivos, definido nas etapas anteriores

# sim.get_files("CID10", uf="BR", year=2010)
dobr_2010 = download(grupo,uf,ano,downloads_sim) # Carrega os dados do SIM
# dobr2010 = download("CID10","BR",2010,'TESTE_EXCLUIR') # Carrega os dados do SIM
# dobr2010
# Out:
# DOTO2010.parquet: 100%|██████████| 16.6k/16.6k [00:00<00:00, 51.3kB/s]

# %%
# Carrega os dados do SIM para os demais anos
# Definição de variáveis
grupo = "CID10" # Agrupamento por CID10
uf = "BR" # A sigla BR carrega dados de todos as unidades federativas
ano = [2019,2020,2021,2022] # Anos do escopo, 2010 e 2022
local = downloads_sim # Local para armazenar os arquivos, definido nas etapas anteriores

# sim.get_files("CID10", uf="BR", year=2010)
dobr2010 = download(grupo,uf,ano,downloads_sim) # Carrega os dados do SIM
# dobr2010 = download("CID10","BR",2010,'TESTE_EXCLUIR') # Carrega os dados do SIM
# dobr2010
# Out:
# 0it [00:00, ?it/s]

# %%
# dodf = dobr.to_dataframe()

# %% [markdown]
# ### Tratamento do arquivo principal
#
# O dicionário do SIM está em "./Estrutura_SIM_para_CD.pdf"
#
# Trabalhamos o CID presente no campo CAUSABAS.
#
# Em razão do escopo da População Estimada (que apresenta dados por Município, mas não de outras variáveis de desigualdade) a primeira versão será um recorte da base DOBR com os dados de CID ('CAUSABAS'), idade (a partir do tratamento de 'DTNASC'), e de Município (a partir do tratamento de 'CODMUNRES').
#
# Por se tratar de doenças evitáveis, o primeiro filtro a ser feito é com base na idade de óbito, que deve ser abaixo de 75 anos.
#
# A idade de óbito está presente no campo IDADE. Ela é composta de 3 dígitos, o primeiro identifica se a contagem é por dias(1), semanas(2), meses (3), ano (4), mais de 100 anos (5).
#
# Em razão disto, vamos desconsiderar todos os valores de dígito 4 e mais de 75 (475).
#
#
# Iremos tratar do arquivo de 2010 separado dos outros anos pela especificade daquele arquivo.

# %%
# Acessar os dados do SIM de 2010 como 1 dataframe

# Definir o diretório onde os arquivos estão localizados
directory = 'downloads_sim_original'

# Listar todos os arquivos na pasta
file_list = os.listdir(directory)

# Filtrar apenas os arquivos parquet
parquet_files = [file for file in file_list if file.endswith('2010.parquet')]

# Inicializar uma lista para armazenar os dataframes
dataframes = []

# Iterar sobre os arquivos parquet e ler cada um em um dataframe
for file in parquet_files:
    file_path = os.path.join(directory, file)
    df = pd.read_parquet(file_path)
    dataframes.append(df)

# Concatenar todos os dataframes em um único dataframe
dobr_10_temp = pd.concat(dataframes, ignore_index=True)

# Exibir informações do dataframe combinado
dobr_10_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1136947 entries, 0 to 1136946
# Data columns (total 60 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   CONTADOR    1133938 non-null  object
#  1   ORIGEM      1136947 non-null  object
#  2   TIPOBITO    1136947 non-null  object
#  3   DTOBITO     1136947 non-null  object
#  4   HORAOBITO   1136947 non-null  object
#  5   NATURAL     1136947 non-null  object
#  6   DTNASC      1136947 non-null  object
#  7   IDADE       1136947 non-null  object
#  8   SEXO        1136947 non-null  object
#  9   RACACOR     1136947 non-null  object
#  10  ESTCIV      1136947 non-null  object
#  11  ESC         1136947 non-null  object
#  12  OCUP        1136947 non-null  object
#  13  CODMUNRES   1136947 non-null  object
#  14  CODBAIRES   1136947 non-null  object
#  15  LOCOCOR     1136947 non-null  object
#  16  CODESTAB    1136947 non-null  object
#  17  CODMUNOCOR  1136947 non-null  object
#  18  CODBAIOCOR  1136947 non-null  object
#  19  IDADEMAE    1136947 non-null  object
#  20  ESCMAE      1136947 non-null  object
#  21  OCUPMAE     1136947 non-null  object
#  22  QTDFILVIVO  1136947 non-null  object
#  23  QTDFILMORT  1136947 non-null  object
#  24  GRAVIDEZ    1136947 non-null  object
#  25  GESTACAO    1136947 non-null  object
#  26  PARTO       1136947 non-null  object
#  27  OBITOPARTO  1136947 non-null  object
#  28  PESO        1136947 non-null  object
#  29  OBITOGRAV   1136947 non-null  object
#  30  OBITOPUERP  1136947 non-null  object
#  31  ASSISTMED   1136947 non-null  object
#  32  EXAME       1136947 non-null  object
#  33  CIRURGIA    1136947 non-null  object
#  34  NECROPSIA   1136947 non-null  object
#  35  LINHAA      1136947 non-null  object
#  36  LINHAB      1136947 non-null  object
#  37  LINHAC      1136947 non-null  object
#  38  LINHAD      1136947 non-null  object
#  39  LINHAII     1136947 non-null  object
#  40  CAUSABAS    1136947 non-null  object
#  41  DTATESTADO  1136947 non-null  object
#  42  CIRCOBITO   1136947 non-null  object
#  43  ACIDTRAB    1136947 non-null  object
#  44  FONTE       1136947 non-null  object
#  45  TPPOS       1136947 non-null  object
#  46  DTINVESTIG  1136947 non-null  object
#  47  CAUSABAS_O  1136947 non-null  object
#  48  DTCADASTRO  1136947 non-null  object
#  49  ATESTANTE   1136947 non-null  object
#  50  FONTEINV    1136947 non-null  object
#  51  DTRECEBIM   1136947 non-null  object
#  52  UFINFORM    1136947 non-null  object
#  53  CB_PRE      1136947 non-null  object
#  54  MORTEPARTO  1136947 non-null  object
#  55  DTCADINF    1136947 non-null  object
#  56  TPOBITOCOR  1136947 non-null  object
#  57  DTCADINV    1136947 non-null  object
#  58  contador    3009 non-null     object
#  59  NUMERODN    3009 non-null     object
# dtypes: object(60)
# memory usage: 520.5+ MB

# %%
# Excluir valores nulos da coluna CAUSABAS
dobr_10_temp01 = dobr_10_temp.dropna(subset=['CAUSABAS'])
dobr_10_temp01.shape[0]
# Out:
# 1136947

# %%
# Reduzir as colunas
dobr_10_temp02 = dobr_10_temp01[['DTOBITO','CAUSABAS', 'CODMUNRES','IDADE']]

# Exibir informações do dataframe após a exclusão
dobr_10_temp02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1136947 entries, 0 to 1136946
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   DTOBITO    1136947 non-null  object
#  1   CAUSABAS   1136947 non-null  object
#  2   CODMUNRES  1136947 non-null  object
#  3   IDADE      1136947 non-null  object
# dtypes: object(4)
# memory usage: 34.7+ MB

# %%
# Arquivo para doenças evitáveis - excluir maiores de 74 anos
dobr_10_temp03 = dobr_10_temp02.copy()

# Substituir valores '     ' e '-' por '0' na coluna IDADE
dobr_10_temp03['IDADE'] = dobr_10_temp03['IDADE'].replace(['     '], '0')

# transformar IDADE em inteiro e excluir valores maiores que 474
dobr_10_temp03['IDADE'] = dobr_10_temp03['IDADE'].astype(int)

dobr_10_temp03.shape[0]
# Out:
# 1136947

# %%
# Filtrar as idades menores de 75
dobr_10_temp04 = dobr_10_temp03[dobr_10_temp03['IDADE'] < 475].reset_index(drop=True)
dobr_10_temp04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722229 entries, 0 to 722228
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   DTOBITO    722229 non-null  object
#  1   CAUSABAS   722229 non-null  object
#  2   CODMUNRES  722229 non-null  object
#  3   IDADE      722229 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 22.0+ MB

# %%
# Carregar e tratar arquivos de DO de outros anos

# Read the parquet files
dobr2019 = pd.read_parquet('downloads_sim_original/DOBR2019.parquet')
dobr2020 = pd.read_parquet('downloads_sim_original/DOBR2020.parquet')
dobr2021 = pd.read_parquet('downloads_sim_original/DOBR2021.parquet')
dobr2022 = pd.read_parquet('downloads_sim_original/DOBR2022.parquet')

# Concatenate the dataframes
dobr_19a22_temp = pd.concat([dobr2019,dobr2020,dobr2021,dobr2022], ignore_index=True)

# %%
dobr_19a22_temp.shape[0]
# Out:
# 6283540

# %%
# Filtrar campos
dobr_19a22_temp01 = dobr_19a22_temp[['DTOBITO','CAUSABAS', 'CODMUNRES','IDADE']]
dobr_19a22_temp01.shape[0]
# Out:
# 6283540

# %%
# transformar IDADE em inteiro 
dobr_19a22_temp02 = dobr_19a22_temp01.copy()
dobr_19a22_temp02['IDADE'] = dobr_19a22_temp02['IDADE'].astype(int)

# %%
# Excluir valores maiores que 474
dobr_19a22_temp03 = dobr_19a22_temp02[dobr_19a22_temp02['IDADE'] < 475]

# Display the combined dataframe
dobr_19a22_temp03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3724693 entries, 1 to 6283539
# Data columns (total 5 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   DTOBITO    object
#  1   CAUSABAS   object
#  2   CODMUNRES  object
#  3   IDADE      int64
#  4   IDADE_     int64
# dtypes: int64(2), object(3)
# memory usage: 170.5+ MB

# %%
# Concatenate the dataframes
dobr_10_19a22_temp = pd.concat([dobr_19a22_temp03,dobr_10_temp04], ignore_index=True)
dobr_10_19a22_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446922 entries, 0 to 4446921
# Data columns (total 5 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   DTOBITO    object
#  1   CAUSABAS   object
#  2   CODMUNRES  object
#  3   IDADE      int64
#  4   IDADE_     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 169.6+ MB

# %%
# Resultado

shape1 = dobr_10_19a22_temp.CAUSABAS.count()

print_y(f" O arquivo de declarações de óbito dos anos de 2010,2019,2020,2021 e 2022 tem o total de {shape1} registros ")
# Out:
#  ==>  O arquivo de declarações de óbito dos anos de 2010,2019,2020,2021 e 2022 tem o total de 4446922 registros

# %%
# Ajustar os campos
dobr_10_19a22_temp01 = dobr_10_19a22_temp.copy()

# assegurar CODMUNRES como string
dobr_10_19a22_temp01['CODMUNRES'] = '_' + dobr_10_19a22_temp01['CODMUNRES'].astype(str).str[:6]

# campo ano_obito formado pelos 4 últimos caracteres de DTOBITO, como número
dobr_10_19a22_temp01['ANO_OBITO'] = '_' + dobr_10_19a22_temp01['DTOBITO'].str[-4:]

# excluir colunas DTOBITO e IDADE
dobr_10_19a22_temp02 = dobr_10_19a22_temp01.drop(['DTOBITO','IDADE','IDADE_'], axis=1)

# Exibir as primeiras linhas do DataFrame resultante
dobr_10_19a22_temp02.head()
# Out:
#   CAUSABAS CODMUNRES ANO_OBITO
# 0     I219   _292740     _2019
# 1     I10    _355100     _2019
# 2     X700   _500630     _2019
# 3     C539   _500500     _2019
# 4     V220   _500627     _2019

# %% [markdown]
# #### Resultados e geração de arquivo DOBR

# %%
# Salvar arquivo em parquet
dobr_10_19a22_temp02.to_parquet('files_clean/dobr_10_19a22.parquet')

# %%
# Contador

# apresentar valor da diferença entre os números de registros de dobr e dobr_filtered

shape_2010 = dobr_10_temp.shape[0]
shape_2019 = dobr2019.shape[0]
shape_2020 = dobr2020.shape[0]
shape_2021 = dobr2021.shape[0]
shape_2022 = dobr2022.shape[0]
shape_all = shape_2010 + shape_2019 + shape_2020 + shape_2021 + shape_2022

print_y(f"""O número de registros de óbitos originais por ano:
        * 2010: {shape_2010}
        * 2019: {shape_2019}
        * 2020: {shape_2020}
        * 2021: {shape_2021}
        * 2022: {shape_2022}
        """)


dif = shape_all - dobr_10_19a22_temp02.shape[0]
print(f"\033[33m ==> O número de registros excluídos por apresentar idade maior de 74 anos foi de {dif} registros\033[0m")
print(f"\033[33m ==> O número de registros de óbitos resultantes é de {dobr_10_19a22_temp02.shape[0]} registros\033[0m")
# Out:
#  ==> O número de registros de óbitos originais por ano:
#         * 2010: 1136947
#         * 2019: 1349801
#         * 2020: 1556824
#         * 2021: 1832649
#         * 2022: 1544266
#
#  ==> O número de registros excluídos por apresentar idade maior de 74 anos foi de 2973565 registros
#  ==> O número de registros de óbitos resultantes é de 4446922 registros

# %% [markdown]
# ## Carga SIM auxiliar
#
# O SIM traz algumas tabelas auxiliares de CID10 e municípios.
#
# Não iremos trazemos estas informações, no entanto, porque iremos utilizar dados de municípios concomitante à população do Censo do IBGE e sobre os CIDs iremos consultar a informações já da lista de doenças evitáveis, conforme OCDE.

# %%
# # Download de tabela auxiliar de CID10
# cid10 = get_CID10_table()
# cid10.head()

# %%
# # Download de tabela auxiliar de CID10
# munic = get_municipios()
# print(munic.head())

# %% [markdown]
# ## Carga externa ao SIM
#
# Iremos carregar informações de fontes externas sobre população e CIDs de doenças evitáveis.

# %% [markdown]
# ##### Carga de CIDs doenças evitáveis - SVS

# %%
# # Download de tabela tratada de CIDs evitáveis de acordo com documentos da SVS

# url = 'https://docs.google.com/spreadsheets/d/1YWurDqnBDMz4ACOEctY9uuQkEm7uSRAogzZETQrLCXk/edit?usp=drive_link'
# # Convert the Google Sheets URL to a CSV export URL
# csv_url = url.replace('/edit?usp=drive_link', '/export?format=csv')

# # Read the CSV data into a pandas DataFrame
# df = pd.read_csv(csv_url)

# # Now you can work with the DataFrame 'df'
# df.head()

# %%
# # Salvar arquivo csv
# df.to_csv('downloads_outros/cid10_evit_svs.csv', index=False)

# %% [markdown]
# ##### Carga de CIDs doenças evitáveis - OCDE

# %%
# # Download de tabela tratada de CIDs evitáveis de acordo com documentos da OCDE
# url = 'https://docs.google.com/spreadsheets/d/1X8AH0zs4PNc_bUpZ3tBvFw2HGpgb9CjShOkwXQ0so_I/edit?usp=sharing'
# # Convert the Google Sheets URL to a CSV export URL
# csv_url = url.replace('/edit?usp=sharing', '/export?format=csv')

# # Read the CSV data into a pandas DataFrame
# ocde_evit = pd.read_csv(csv_url)

# # Now you can work with the DataFrame 'df'
# ocde_evit.head()
# Out:
#             avoid_flag           prevent_flag treat_flag                Group  \
# 0  Avoidable mortality  Preventable mortality        NaN  Infectious diseases
# 1  Avoidable mortality  Preventable mortality        NaN  Infectious diseases
# 2  Avoidable mortality  Preventable mortality        NaN  Infectious diseases
# 3  Avoidable mortality  Preventable mortality        NaN  Infectious diseases
# 4  Avoidable mortality  Preventable mortality        NaN  Infectious diseases
#
#                      Causes of deaths  \
# 0                 Intestinal diseases
# 1  Diphtheria, Tetanus, Poliomyelitis
# 2  Diphtheria, Tetanus, Poliomyelitis
# 3  Diphtheria, Tetanus, Poliomyelitis
# 4                      Whooping cough
#
#                              Rationale for inclusion            Range cid_pai
# 0  Most of these infections can be prevented thro...        (A00-A09)      A0
# 1  Most of these infections can be prevented thro...  (A35, A36, A80)     A35
# 2  Most of these infections can be prevented thro...  (A35, A36, A80)     A36
# 3  Most of these infections can be prevented thro...  (A35, A36, A80)     A80
# 4  Most of these infections can be prevented thro...            (A37)     A37

# %%
ocde_evit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avoid_flag               346 non-null    object
#  1   prevent_flag             189 non-null    object
#  2   treat_flag               184 non-null    object
#  3   Group                    346 non-null    object
#  4   Causes of deaths         346 non-null    object
#  5   Rationale for inclusion  346 non-null    object
#  6   Range                    346 non-null    object
#  7   cid_pai                  346 non-null    object
# dtypes: object(8)
# memory usage: 21.8+ KB

# %% [markdown]
# ## População Censo

# %% [markdown]
# ### Carga de População Censo
#
#
# Os dados populacionais são os dos Censos de 2010 e 2022.
#
# Nesta v2, não iremos tratar com variáveis de sexo, raça e faixa etária (para calcular menores de 75 anos).
#
# A fonte de dados para gerar os arquivos ou o endereço do caminho SIDRA, é https://sidra.ibge.gov.br/Tabela/9605.
#
# Nota da v.2 : iremos trazer os dados do Censo sem precisar desagregar por sexo e raça-cor e consideramos que não será necessário trazer dados por UF, estes podem ser agregados depois a partir dos dados de município.

# %%
# # Definir a URL
# url = 'https://sidra.ibge.gov.br/geratabela?format=us.csv&name=tabela9606.csv&terr=NCS&rank=-&query=t/9606/n3/all/n6/all/v/allxp/p/all/c86/95251/c2/6794/c287/6653,49108,49109,60040,60041,93098,100362/l/,v%2Bc287,p%2Bt%2Bc86%2Bc2&verComplementos2=false&verComplementos1=false&omitirIndentacao=false&abreviarRotulos=false&exibirNotas=false&agruparNoCabecalho=false'

# # Ler os dados da URL em um DataFrame
# # censo_pop = pd.read_json(url)
# ibge_download_ = pd.read_csv(url, skiprows=3, dtype=str)

# # Exibir as primeiras linhas do DataFrame
# ibge_download_.head()
# Out:
#     Ano Nível Cód. Unidade da Federação e Município Cor ou raça   Sexo  \
# 0  2010    UF   11                         Rondônia       Total  Total
# 1  2010    UF   12                             Acre       Total  Total
# 2  2010    UF   13                         Amazonas       Total  Total
# 3  2010    UF   14                          Roraima       Total  Total
# 4  2010    UF   15                             Pará       Total  Total
#
#      Total 75 a 79 anos 80 a 84 anos 85 a 89 anos 90 a 94 anos 95 a 99 anos  \
# 0  1562409        13015         7291         3170         1126          330
# 1   733559         5508         3574         1790          737          300
# 2  3483985        24686        14803         7829         3405         1249
# 3   450479         2575         1586          809          324          100
# 4  7581051        62725        37009        18075         8912         3349
#
#   100 anos ou mais
# 0               82
# 1               91
# 2              415
# 3               35
# 4              899

# %%
# Exibir informaçãoes gerais do DataFrame
ibge_download_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11214 entries, 0 to 11213
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Ano                               11213 non-null  object
#  1   Nível                             11201 non-null  object
#  2   Cód.                              11194 non-null  object
#  3   Unidade da Federação e Município  11194 non-null  object
#  4   Cor ou raça                       11194 non-null  object
#  5   Sexo                              11194 non-null  object
#  6   Total                             11194 non-null  object
#  7   75 a 79 anos                      11194 non-null  object
#  8   80 a 84 anos                      11194 non-null  object
#  9   85 a 89 anos                      11194 non-null  object
#  10  90 a 94 anos                      11194 non-null  object
#  11  95 a 99 anos                      11194 non-null  object
#  12  100 anos ou mais                  11194 non-null  object
# dtypes: object(13)
# memory usage: 1.1+ MB

# %%
# Primeira linha de tratamento para salvar arquivo

# Excluir notas e comentários do arquivo
ibge_download = ibge_download_.dropna(subset=['Total']).reset_index(drop=True)

# Exibir as primeiras linhas do DataFrame
ibge_download.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11194 entries, 0 to 11193
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Ano                               11194 non-null  object
#  1   Nível                             11194 non-null  object
#  2   Cód.                              11194 non-null  object
#  3   Unidade da Federação e Município  11194 non-null  object
#  4   Cor ou raça                       11194 non-null  object
#  5   Sexo                              11194 non-null  object
#  6   Total                             11194 non-null  object
#  7   75 a 79 anos                      11194 non-null  object
#  8   80 a 84 anos                      11194 non-null  object
#  9   85 a 89 anos                      11194 non-null  object
#  10  90 a 94 anos                      11194 non-null  object
#  11  95 a 99 anos                      11194 non-null  object
#  12  100 anos ou mais                  11194 non-null  object
# dtypes: object(13)
# memory usage: 1.1+ MB

# %%
# Segunda linha de tratamento para salvar arquivo

# Excluir colunas de "Cor ou raça" e "Sexo"
ibge_download01 = ibge_download.drop(columns=['Sexo','Cor ou raça'])

# Renomear colunas
ibge_download01.rename(columns={'Unidade da Federação e Município': 'unidade_no'}, inplace=True)

# Exibir informações gerais do dataframe
ibge_download01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11194 entries, 0 to 11193
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ano               11194 non-null  object
#  1   Nível             11194 non-null  object
#  2   Cód.              11194 non-null  object
#  3   unidade_no        11194 non-null  object
#  4   Total             11194 non-null  object
#  5   75 a 79 anos      11194 non-null  object
#  6   80 a 84 anos      11194 non-null  object
#  7   85 a 89 anos      11194 non-null  object
#  8   90 a 94 anos      11194 non-null  object
#  9   95 a 99 anos      11194 non-null  object
#  10  100 anos ou mais  11194 non-null  object
# dtypes: object(11)
# memory usage: 962.1+ KB

# %%
# Salvar arquivo de população do Censo
ibge_download01.to_parquet('downloads_outros/censo_pop_raw.parquet')

# %% [markdown]
# ### Tratamento de População Censo Municípios

# %%
# Carga de arquivo de População do Censo
censo_pop_temp = pd.read_parquet('downloads_outros/censo_pop_raw.parquet')

# %%
censo_pop_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11194 entries, 0 to 11193
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ano               11194 non-null  object
#  1   Nível             11194 non-null  object
#  2   Cód.              11194 non-null  object
#  3   unidade_no        11194 non-null  object
#  4   Total             11194 non-null  object
#  5   75 a 79 anos      11194 non-null  object
#  6   80 a 84 anos      11194 non-null  object
#  7   85 a 89 anos      11194 non-null  object
#  8   90 a 94 anos      11194 non-null  object
#  9   95 a 99 anos      11194 non-null  object
#  10  100 anos ou mais  11194 non-null  object
# dtypes: object(11)
# memory usage: 962.1+ KB

# %%
censo_pop_temp.head()
# Out:
#     Ano Nível Cód. unidade_no    Total 75 a 79 anos 80 a 84 anos 85 a 89 anos  \
# 0  2010    UF   11   Rondônia  1562409        13015         7291         3170
# 1  2010    UF   12       Acre   733559         5508         3574         1790
# 2  2010    UF   13   Amazonas  3483985        24686        14803         7829
# 3  2010    UF   14    Roraima   450479         2575         1586          809
# 4  2010    UF   15       Pará  7581051        62725        37009        18075
#
#   90 a 94 anos 95 a 99 anos 100 anos ou mais
# 0         1126          330               82
# 1          737          300               91
# 2         3405         1249              415
# 3          324          100               35
# 4         8912         3349              899

# %%
# Identificar a classificação de unidades federativas
print(f'Unidades federativas do arquivo Censo_pop: {censo_pop_temp.Nível.unique()}')

# Apresentar os anos do Censo
print(f'Anos do arquivo Censo_pop: {censo_pop_temp.Ano.unique()}')
# Out:
# Unidades federativas do arquivo Censo_pop: ['UF' 'MU']
# Anos do arquivo Censo_pop: ['2010' '2022']

# %%
# # Filtrar os dados apenas de município
# censo_pop_mun = censo_pop_raw[censo_pop_raw['Nível'] == 'MU']
# censo_pop_mun.info()

# %%
# Preparar colunas para conseguir valores da população até 74 anos

# Colunas para transformar em inteiro
cols_age = ['Total','75 a 79 anos', '80 a 84 anos', '85 a 89 anos','90 a 94 anos', '95 a 99 anos', '100 anos ou mais']
# para todas as colunas identificar substituir '-' por 0
censo_pop_temp01 = censo_pop_temp.copy()
censo_pop_temp01[cols_age] = censo_pop_temp01[cols_age].replace('-',0)

# transformar todas as colunas definidas para formato integer
censo_pop_temp01[cols_age] = censo_pop_temp01[cols_age].apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)
censo_pop_temp01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11194 entries, 0 to 11193
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ano               11194 non-null  object
#  1   Nível             11194 non-null  object
#  2   Cód.              11194 non-null  object
#  3   unidade_no        11194 non-null  object
#  4   Total             11194 non-null  int64
#  5   75 a 79 anos      11194 non-null  int64
#  6   80 a 84 anos      11194 non-null  int64
#  7   85 a 89 anos      11194 non-null  int64
#  8   90 a 94 anos      11194 non-null  int64
#  9   95 a 99 anos      11194 non-null  int64
#  10  100 anos ou mais  11194 non-null  int64
# dtypes: int64(7), object(4)
# memory usage: 962.1+ KB

# %%
# Gerar coluna de população total até 74 anos
cols_age_over75 = ['75 a 79 anos', '80 a 84 anos', '85 a 89 anos','90 a 94 anos', '95 a 99 anos', '100 anos ou mais']

censo_pop_temp02 = censo_pop_temp01.copy()

# Subtrair a população de 75 anos ou mais da população total
censo_pop_temp02['pop_under74'] = censo_pop_temp02['Total'] - censo_pop_temp02[cols_age_over75].sum(axis=1)

# Excluir colunar cols_age_over75 e 0 a 4 anos
censo_pop_temp02.drop(columns=cols_age_over75, inplace=True)

# Renomear coluna Total para pop_total
censo_pop_temp02.rename(columns={'Total': 'pop_total'}, inplace=True)

# mostrar dados gerais da tabela após transformações
print(censo_pop_temp02.shape[0])
censo_pop_temp02.head()
# Out:
# 11194
#     Ano Nível Cód. unidade_no  pop_total  pop_under74
# 0  2010    UF   11   Rondônia    1562409      1537395
# 1  2010    UF   12       Acre     733559       721559
# 2  2010    UF   13   Amazonas    3483985      3431598
# 3  2010    UF   14    Roraima     450479       445050
# 4  2010    UF   15       Pará    7581051      7450082

# %%
# Gerar informação de UF a partir do split de 'Município', com o dividor '('
censo_pop_temp03 = censo_pop_temp02.copy()
censo_pop_temp03['UF'] = censo_pop_temp03['unidade_no'].str.split('(', expand=True)[1].str.replace(')','')
censo_pop_temp03['uf_co'] = '_' + censo_pop_temp03['Cód.'].astype(str).str[:2]
# censo_pop_temp03['unidade_no'] = censo_pop_temp03['unidade_no'].str.split('(', expand=True)[0] # Permancer o código de UF depois do nome do município

# mostrar dados gerais da tabela após transformações
print(censo_pop_temp03.shape[0])
censo_pop_temp03.head()
# Out:
# 11194
#     Ano Nível Cód. unidade_no  pop_total  pop_under74    UF uf_co
# 0  2010    UF   11   Rondônia    1562409      1537395  None   _11
# 1  2010    UF   12       Acre     733559       721559  None   _12
# 2  2010    UF   13   Amazonas    3483985      3431598  None   _13
# 3  2010    UF   14    Roraima     450479       445050  None   _14
# 4  2010    UF   15       Pará    7581051      7450082  None   _15

# %%
# Dividir arquivos em UF e Municípios

# Criar arquivo de UF
censo_pop_uf_temp = censo_pop_temp03[censo_pop_temp03['Nível'] == 'UF'].reset_index(drop=True)

# Criar arquivo de Municípios
censo_pop_mun_temp = censo_pop_temp03[censo_pop_temp03['Nível'] == 'MU'].reset_index(drop=True)

# mostrar dados gerais da tabela após transformações
print(f'Registro da tabela censo_pop_uf_temp: {censo_pop_uf_temp.shape[0]}')
print(tabulate(censo_pop_uf_temp.head(), headers='keys', tablefmt='psql'))
print(f'Registro da tabela censo_pop_mun_temp: {censo_pop_mun_temp.shape[0]}')
print(tabulate(censo_pop_mun_temp.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela censo_pop_uf_temp: 54
# +----+-------+---------+--------+--------------+-------------+---------------+------+---------+
# |    |   Ano | Nível   |   Cód. | unidade_no   |   pop_total |   pop_under74 | UF   | uf_co   |
# |----+-------+---------+--------+--------------+-------------+---------------+------+---------|
# |  0 |  2010 | UF      |     11 | Rondônia     |     1562409 |       1537395 |      | _11     |
# |  1 |  2010 | UF      |     12 | Acre         |      733559 |        721559 |      | _12     |
# |  2 |  2010 | UF      |     13 | Amazonas     |     3483985 |       3431598 |      | _13     |
# |  3 |  2010 | UF      |     14 | Roraima      |      450479 |        445050 |      | _14     |
# |  4 |  2010 | UF      |     15 | Pará         |     7581051 |       7450082 |      | _15     |
# +----+-------+---------+--------+--------------+-------------+---------------+------+---------+
# Registro da tabela censo_pop_mun_temp: 11140
# +----+-------+---------+---------+----------------------------+-------------+---------------+------+---------+
# |    |   Ano | Nível   |    Cód. | unidade_no                 |   pop_total |   pop_under74 | UF   | uf_co   |
# |----+-------+---------+---------+----------------------------+-------------+---------------+------+---------|
# |  0 |  2010 | MU      | 1100015 | Alta Floresta D'Oeste (RO) |       24392 |         23948 | RO   | _11     |
# |  1 |  2010 | MU      | 1100023 | Ariquemes (RO)             |       90353 |         89037 | RO   | _11     |
# |  2 |  2010 | MU      | 1100031 | Cabixi (RO)                |        6313 |          6180 | RO   | _11     |
# |  3 |  2010 | MU      | 1100049 | Cacoal (RO)                |       78574 |         76947 | RO   | _11     |
# |  4 |  2010 | MU      | 1100056 | Cerejeiras (RO)            |       17029 |         16646 | RO   | _11     |
# +----+-------+---------+---------+----------------------------+-------------+---------------+------+---------+

# %%
# Preparar para salvar arquivo de UF
censo_pop_uf_temp01 = censo_pop_uf_temp.copy()

# Excluir colunas desnecessárias
censo_pop_uf_temp01.drop(columns=['Cód.','Nível','UF'], inplace=True)

# Renomear coluna unidade_no para uf_no
censo_pop_uf_temp01.rename(columns={'unidade_no': 'uf_no'}, inplace=True)

# mostrar dados gerais da tabela após transformações
print(f'Registro da tabela : {censo_pop_uf_temp01.shape[0]}')
print(tabulate(censo_pop_uf_temp01.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 54
# +----+-------+----------+-------------+---------------+---------+
# |    |   Ano | uf_no    |   pop_total |   pop_under74 | uf_co   |
# |----+-------+----------+-------------+---------------+---------|
# |  0 |  2010 | Rondônia |     1562409 |       1537395 | _11     |
# |  1 |  2010 | Acre     |      733559 |        721559 | _12     |
# |  2 |  2010 | Amazonas |     3483985 |       3431598 | _13     |
# |  3 |  2010 | Roraima  |      450479 |        445050 | _14     |
# |  4 |  2010 | Pará     |     7581051 |       7450082 | _15     |
# +----+-------+----------+-------------+---------------+---------+

# %%
# Preparar para salvar arquivo de Municipios
censo_pop_mun_temp01 = censo_pop_mun_temp.copy()

# Mudar o formato de mun_cod para string e extrair os primeiros 7 dígitos
censo_pop_mun_temp01['mun_cod_sim'] = censo_pop_mun_temp01['Cód.'].astype(str).str[:6]

# Acrescentar um '_' no início do valor da coluna mun_cod
censo_pop_mun_temp01['mun_cod_sim'] = '_' + censo_pop_mun_temp01['mun_cod_sim'].astype(str)

# Renomear coluna unidade_no para uf_no
censo_pop_mun_temp01.rename(columns={'unidade_no': 'mun_no'}, inplace=True)

# Excluir colunas desnecessárias
censo_pop_mun_temp01.drop(columns=['Cód.','Nível'], inplace=True)

# Ordenar as colunas
censo_pop_mun_temp02 = censo_pop_mun_temp01[['Ano','uf_co','UF','mun_cod_sim','mun_no','pop_total','pop_under74']]

# mostrar dados gerais da tabela após transformações
print(f'Registro da tabela : {censo_pop_mun_temp02.shape[0]}')
print(tabulate(censo_pop_mun_temp02.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 11140
# +----+-------+---------+------+---------------+----------------------------+-------------+---------------+
# |    |   Ano | uf_co   | UF   | mun_cod_sim   | mun_no                     |   pop_total |   pop_under74 |
# |----+-------+---------+------+---------------+----------------------------+-------------+---------------|
# |  0 |  2010 | _11     | RO   | _110001       | Alta Floresta D'Oeste (RO) |       24392 |         23948 |
# |  1 |  2010 | _11     | RO   | _110002       | Ariquemes (RO)             |       90353 |         89037 |
# |  2 |  2010 | _11     | RO   | _110003       | Cabixi (RO)                |        6313 |          6180 |
# |  3 |  2010 | _11     | RO   | _110004       | Cacoal (RO)                |       78574 |         76947 |
# |  4 |  2010 | _11     | RO   | _110005       | Cerejeiras (RO)            |       17029 |         16646 |
# +----+-------+---------+------+---------------+----------------------------+-------------+---------------+

# %% [markdown]
# #### Arquivo pronto - censo por municípios e por UF

# %%
# Arquivo de População Censo Tratado (pronto para merge)
censo_pop_mun_temp02.to_parquet('files_clean/censo_pop_mun.parquet')

# %%
# Salvar arquivo de População do Censo uf
censo_pop_uf_temp01.to_parquet('files_clean/censo_pop_uf.parquet')

# %% [markdown]
# ## Merge de dados de CID e População no arquivo principal

# %% [markdown]
# ### Merge de dados de CID

# %%
ocde_evit_temp = pd.read_csv('downloads_outros/cid10_evit_ocde.csv')
ocde_evit_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avoid_flag               346 non-null    object
#  1   prevent_flag             189 non-null    object
#  2   treat_flag               184 non-null    object
#  3   Group                    346 non-null    object
#  4   Causes of deaths         346 non-null    object
#  5   Rationale for inclusion  346 non-null    object
#  6   Range                    346 non-null    object
#  7   cid_pai                  346 non-null    object
# dtypes: object(8)
# memory usage: 21.8+ KB

# %%
# Gerar nova tabela com valores únicos de CAUSABAS
dobr_evit_merged_temp = pd.read_parquet('files_clean/dobr_10_19a22.parquet')
causas_unicas = dobr_evit_merged_temp['CAUSABAS'].unique()

# Converter para DataFrame
df_causas_unicas = pd.DataFrame(causas_unicas, columns=['CAUSABAS'])

# Exibir as primeiras linhas do DataFrame
df_causas_unicas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11895 entries, 0 to 11894
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CAUSABAS  11895 non-null  object
# dtypes: object(1)
# memory usage: 93.1+ KB

# %%
# Fazer merge da lista de causas_unicas com a lista de causas evitáveis

df_a = df_causas_unicas
column_a = 'CAUSABAS'
df_b = ocde_evit_temp
column_b = 'cid_pai'
column_return = 'avoid_flag'



# Função para verificar a correspondência e retornar a classificação
def verificar_correspondencia(row):
    for index, row_b in df_b.iterrows():
        if row[column_a].startswith(row_b[column_b]):
            return row_b[column_return]
    return 'causa não evitável'

# Aplicando a função a cada linha do DataFrame A
df_a['classificacao'] = df_a.apply(verificar_correspondencia, axis=1)

print(tabulate(df_a))
# Out:
# -----  ----  -------------------
#     0  I219  Avoidable mortality
#     1  I10   Avoidable mortality
#     2  X700  Avoidable mortality
#     3  C539  causa não evitável
#     4  V220  Avoidable mortality
#     5  W019  Avoidable mortality
#     6  X709  Avoidable mortality
#     7  G809  causa não evitável
#     8  G309  causa não evitável
#     9  J440  Avoidable mortality
#    10  B207  Avoidable mortality
#    11  J449  Avoidable mortality
#    12  V899  Avoidable mortality
#    13  I110  Avoidable mortality
#    14  L030  causa não evitável
#    15  J189  Avoidable mortality
#    16  I619  Avoidable mortality
#    17  C480  causa não evitável
#    18  J850  Avoidable mortality
#    19  C61   causa não evitável
#    20  N390  causa não evitável
#    21  A419  causa não evitável
#    22  C229  Avoidable mortality
#    23  C920  causa não evitável
#    24  N170  Avoidable mortality
#    25  I340  causa não evitável
#    26  C189  causa não evitável
#    27  C23   causa não evitável
#    28  X954  Avoidable mortality
#    29  V489  Avoidable mortality
#    30  V299  Avoidable mortality
#    31  E149  Avoidable mortality
#    32  C19   causa não evitável
#    33  F102  Avoidable mortality
#    34  J90   Avoidable mortality
#    35  J121  Avoidable mortality
#    36  O159  causa não evitável
#    37  W849  Avoidable mortality
#    38  C108  causa não evitável
#    39  I713  Avoidable mortality
#    40  K904  causa não evitável
#    41  X999  Avoidable mortality
#    42  C169  Avoidable mortality
#    43  I64   Avoidable mortality
#    44  J188  Avoidable mortality
#    45  A90   causa não evitável
#    46  W235  Avoidable mortality
#    47  R98   causa não evitável
#    48  E119  Avoidable mortality
#    49  C80   causa não evitável
#    50  C349  Avoidable mortality
#    51  J159  Avoidable mortality
#    52  C900  causa não evitável
#    53  R960  causa não evitável
#    54  R570  causa não evitável
#    55  C541  causa não evitável
#    56  R99   causa não evitável
#    57  J068  Avoidable mortality
#    58  D619  causa não evitável
#    59  R092  causa não evitável
#    60  G122  causa não evitável
#    61  A162  Avoidable mortality
#    62  C260  causa não evitável
#    63  C835  causa não evitável
#    64  N119  causa não evitável
#    65  C509  causa não evitável
#    66  K746  Avoidable mortality
#    67  K709  Avoidable mortality
#    68  Y350  causa não evitável
#    69  K703  Avoidable mortality
#    70  X959  Avoidable mortality
#    71  E141  Avoidable mortality
#    72  V449  Avoidable mortality
#    73  C679  causa não evitável
#    74  X990  Avoidable mortality
#    75  B203  Avoidable mortality
#    76  V680  Avoidable mortality
#    77  C56   causa não evitável
#    78  I258  Avoidable mortality
#    79  G049  causa não evitável
#    80  P291  Avoidable mortality
#    81  I694  Avoidable mortality
#    82  I509  causa não evitável
#    83  K920  causa não evitável
#    84  V134  Avoidable mortality
#    85  M869  causa não evitável
#    86  Y349  Avoidable mortality
#    87  X470  Avoidable mortality
#    88  J180  Avoidable mortality
#    89  I420  causa não evitável
#    90  I422  causa não evitável
#    91  Y244  Avoidable mortality
#    92  V011  Avoidable mortality
#    93  E788  causa não evitável
#    94  F602  causa não evitável
#    95  G405  Avoidable mortality
#    96  J841  causa não evitável
#    97  J969  causa não evitável
#    98  I712  Avoidable mortality
#    99  I678  Avoidable mortality
#   100  I517  causa não evitável
#   101  P017  Avoidable mortality
#   102  B200  Avoidable mortality
#   103  P000  Avoidable mortality
#   104  K578  causa não evitável
#   105  B24   Avoidable mortality
#   106  A09   Avoidable mortality
#   107  E117  Avoidable mortality
#   108  I500  causa não evitável
#   109  B572  causa não evitável
#   110  G410  Avoidable mortality
#   111  X708  Avoidable mortality
#   112  J111  Avoidable mortality
#   113  P249  Avoidable mortality
#   114  C910  Avoidable mortality
#   115  N19   Avoidable mortality
#   116  I802  Avoidable mortality
#   117  I249  Avoidable mortality
#   118  J81   Avoidable mortality
#   119  F500  causa não evitável
#   120  C139  causa não evitável
#   121  I255  Avoidable mortality
#   122  W189  Avoidable mortality
#   123  I210  Avoidable mortality
#   124  I269  Avoidable mortality
#   125  C159  causa não evitável
#   126  J459  Avoidable mortality
#   127  J441  Avoidable mortality
#   128  J80   Avoidable mortality
#   129  V549  Avoidable mortality
#   130  G404  Avoidable mortality
#   131  Y049  Avoidable mortality
#   132  K830  Avoidable mortality
#   133  W199  Avoidable mortality
#   134  K296  causa não evitável
#   135  I714  Avoidable mortality
#   136  X590  Avoidable mortality
#   137  C449  causa não evitável
#   138  C140  causa não evitável
#   139  Y218  Avoidable mortality
#   140  B201  Avoidable mortality
#   141  E105  Avoidable mortality
#   142  J439  Avoidable mortality
#   143  C069  causa não evitável
#   144  I059  Avoidable mortality
#   145  E271  Avoidable mortality
#   146  J849  causa não evitável
#   147  V244  Avoidable mortality
#   148  K550  causa não evitável
#   149  W109  Avoidable mortality
#   150  C20   causa não evitável
#   151  E669  causa não evitável
#   152  I639  Avoidable mortality
#   153  C12   causa não evitável
#   154  K551  causa não evitável
#   155  C64   causa não evitável
#   156  C259  causa não evitável
#   157  K579  causa não evitável
#   158  C168  Avoidable mortality
#   159  C719  causa não evitável
#   160  Q249  Avoidable mortality
#   161  Q793  causa não evitável
#   162  C717  causa não evitável
#   163  Y269  Avoidable mortality
#   164  K800  Avoidable mortality
#   165  K767  causa não evitável
#   166  I609  Avoidable mortality
#   167  W184  Avoidable mortality
#   168  C783  causa não evitável
#   169  E109  Avoidable mortality
#   170  I690  Avoidable mortality
#   171  I710  Avoidable mortality
#   172  V031  Avoidable mortality
#   173  I213  Avoidable mortality
#   174  Y009  Avoidable mortality
#   175  V249  Avoidable mortality
#   176  E115  Avoidable mortality
#   177  D578  causa não evitável
#   178  P220  Avoidable mortality
#   179  I850  causa não evitável
#   180  I132  Avoidable mortality
#   181  C348  Avoidable mortality
#   182  C329  causa não evitável
#   183  V499  Avoidable mortality
#   184  E46   causa não evitável
#   185  C919  causa não evitável
#   186  A91   causa não evitável
#   187  J690  Avoidable mortality
#   188  I120  Avoidable mortality
#   189  I229  Avoidable mortality
#   190  E147  Avoidable mortality
#   191  B690  causa não evitável
#   192  C499  causa não evitável
#   193  D099  causa não evitável
#   194  F03   causa não evitável
#   195  I743  causa não evitável
#   196  K566  causa não evitável
#   197  C109  causa não evitável
#   198  C182  causa não evitável
#   199  N200  Avoidable mortality
#   200  D381  causa não evitável
#   201  M629  causa não evitável
#   202  K850  Avoidable mortality
#   203  I48   causa não evitável
#   204  I099  Avoidable mortality
#   205  C179  causa não evitável
#   206  K740  Avoidable mortality
#   207  I38   causa não evitável
#   208  C760  causa não evitável
#   209  E112  Avoidable mortality
#   210  F172  causa não evitável
#   211  K768  causa não evitável
#   212  C178  causa não evitável
#   213  W698  Avoidable mortality
#   214  V092  Avoidable mortality
#   215  Y041  Avoidable mortality
#   216  K754  causa não evitável
#   217  C490  causa não evitável
#   218  K717  causa não evitável
#   219  X680  Avoidable mortality
#   220  Y007  Avoidable mortality
#   221  V284  Avoidable mortality
#   222  X997  Avoidable mortality
#   223  V239  Avoidable mortality
#   224  Q913  causa não evitável
#   225  V892  Avoidable mortality
#   226  I514  causa não evitável
#   227  K859  Avoidable mortality
#   228  C161  Avoidable mortality
#   229  E640  causa não evitável
#   230  D730  causa não evitável
#   231  D430  causa não evitável
#   232  J219  Avoidable mortality
#   233  C710  causa não evitável
#   234  X950  Avoidable mortality
#   235  J129  Avoidable mortality
#   236  J118  Avoidable mortality
#   237  V021  Avoidable mortality
#   238  X760  Avoidable mortality
#   239  V439  Avoidable mortality
#   240  E107  Avoidable mortality
#   241  G20   causa não evitável
#   242  M623  causa não evitável
#   243  V480  Avoidable mortality
#   244  V230  Avoidable mortality
#   245  N189  Avoidable mortality
#   246  K729  causa não evitável
#   247  C482  causa não evitável
#   248  N179  Avoidable mortality
#   249  I739  Avoidable mortality
#   250  I260  Avoidable mortality
#   251  D751  causa não evitável
#   252  K264  Avoidable mortality
#   253  I638  Avoidable mortality
#   254  E059  Avoidable mortality
#   255  K458  Avoidable mortality
#   256  D860  causa não evitável
#   257  P010  Avoidable mortality
#   258  P001  Avoidable mortality
#   259  M321  causa não evitável
#   260  Y204  Avoidable mortality
#   261  Y249  Avoidable mortality
#   262  G629  causa não evitável
#   263  C138  causa não evitável
#   264  I830  causa não evitável
#   265  E140  Avoidable mortality
#   266  G409  Avoidable mortality
#   267  C029  causa não evitável
#   268  I251  Avoidable mortality
#   269  P599  Avoidable mortality
#   270  I461  causa não evitável
#   271  K255  Avoidable mortality
#   272  K261  Avoidable mortality
#   273  B208  Avoidable mortality
#   274  X955  Avoidable mortality
#   275  C240  causa não evitável
#   276  K769  causa não evitável
#   277  K828  Avoidable mortality
#   278  C383  causa não evitável
#   279  C768  causa não evitável
#   280  Y344  Avoidable mortality
#   281  B573  causa não evitável
#   282  Y859  causa não evitável
#   283  P240  Avoidable mortality
#   284  E142  Avoidable mortality
#   285  K760  causa não evitável
#   286  I711  Avoidable mortality
#   287  I499  causa não evitável
#   288  C439  Avoidable mortality
#   289  K819  Avoidable mortality
#   290  B909  Avoidable mortality
#   291  X099  Avoidable mortality
#   292  F209  causa não evitável
#   293  E145  Avoidable mortality
#   294  X994  Avoidable mortality
#   295  W748  Avoidable mortality
#   296  V093  Avoidable mortality
#   297  G919  causa não evitável
#   298  Q02   causa não evitável
#   299  M313  causa não evitável
#   300  V435  Avoidable mortality
#   301  V475  Avoidable mortality
#   302  V446  Avoidable mortality
#   303  V234  Avoidable mortality
#   304  V436  Avoidable mortality
#   305  V445  Avoidable mortality
#   306  W207  Avoidable mortality
#   307  F109  Avoidable mortality
#   308  K262  Avoidable mortality
#   309  J47   Avoidable mortality
#   310  P969  Avoidable mortality
#   311  C716  causa não evitável
#   312  J984  causa não evitável
#   313  X599  Avoidable mortality
#   314  C959  causa não evitável
#   315  K571  causa não evitável
#   316  D219  Avoidable mortality
#   317  X952  Avoidable mortality
#   318  A86   causa não evitável
#   319  X958  Avoidable mortality
#   320  W697  Avoidable mortality
#   321  W683  Avoidable mortality
#   322  X998  Avoidable mortality
#   323  I350  causa não evitável
#   324  I511  causa não evitável
#   325  E789  causa não evitável
#   326  C268  causa não evitável
#   327  E148  Avoidable mortality
#   328  C250  causa não evitável
#   329  L89   causa não evitável
#   330  C859  causa não evitável
#   331  K810  Avoidable mortality
#   332  Y129  Avoidable mortality
#   333  I119  Avoidable mortality
#   334  D649  causa não evitável
#   335  X934  Avoidable mortality
#   336  X930  Avoidable mortality
#   337  W344  Avoidable mortality
#   338  E110  Avoidable mortality
#   339  N180  Avoidable mortality
#   340  K829  Avoidable mortality
#   341  K351  Avoidable mortality
#   342  L039  causa não evitável
#   343  E782  causa não evitável
#   344  D500  Avoidable mortality
#   345  Y002  Avoidable mortality
#   346  V585  Avoidable mortality
#   347  G09   causa não evitável
#   348  C73   Avoidable mortality
#   349  P368  Avoidable mortality
#   350  Y838  Avoidable mortality
#   351  P070  Avoidable mortality
#   352  P290  Avoidable mortality
#   353  Y299  Avoidable mortality
#   354  V484  Avoidable mortality
#   355  V235  Avoidable mortality
#   356  V144  Avoidable mortality
#   357  X728  Avoidable mortality
#   358  Q792  causa não evitável
#   359  I259  Avoidable mortality
#   360  I471  causa não evitável
#   361  E039  Avoidable mortality
#   362  K316  causa não evitável
#   363  W209  Avoidable mortality
#   364  C609  causa não evitável
#   365  C340  Avoidable mortality
#   366  N739  Avoidable mortality
#   367  D759  causa não evitável
#   368  C925  causa não evitável
#   369  C844  causa não evitável
#   370  I693  Avoidable mortality
#   371  K572  causa não evitável
#   372  J181  Avoidable mortality
#   373  Y004  Avoidable mortality
#   374  Y340  Avoidable mortality
#   375  J988  causa não evitável
#   376  G938  causa não evitável
#   377  C443  causa não evitável
#   378  O96   causa não evitável
#   379  X629  Avoidable mortality
#   380  C696  causa não evitável
#   381  C55   causa não evitável
#   382  J960  causa não evitável
#   383  C508  causa não evitável
#   384  W798  Avoidable mortality
#   385  V289  Avoidable mortality
#   386  B217  Avoidable mortality
#   387  I501  causa não evitável
#   388  I358  causa não evitável
#   389  I348  causa não evitável
#   390  D439  causa não evitável
#   391  N188  Avoidable mortality
#   392  Y198  Avoidable mortality
#   393  A418  causa não evitável
#   394  O998  causa não evitável
#   395  C901  causa não evitável
#   396  B181  Avoidable mortality
#   397  Q909  causa não evitável
#   398  M009  causa não evitável
#   399  X802  Avoidable mortality
#   400  W180  Avoidable mortality
#   401  V224  Avoidable mortality
#   402  K561  causa não evitável
#   403  A46   causa não evitável
#   404  K922  causa não evitável
#   405  K122  causa não evitável
#   406  C787  causa não evitável
#   407  I608  Avoidable mortality
#   408  J848  causa não evitável
#   409  W182  Avoidable mortality
#   410  I309  causa não evitável
#   411  X939  Avoidable mortality
#   412  I519  causa não evitável
#   413  E108  Avoidable mortality
#   414  B205  Avoidable mortality
#   415  I959  causa não evitável
#   416  C780  causa não evitável
#   417  D693  causa não evitável
#   418  C01   causa não evitável
#   419  A158  Avoidable mortality
#   420  P027  Avoidable mortality
#   421  Q211  Avoidable mortality
#   422  G35   causa não evitável
#   423  G112  causa não evitável
#   424  Y200  Avoidable mortality
#   425  I671  Avoidable mortality
#   426  R961  causa não evitável
#   427  P029  Avoidable mortality
#   428  P073  Avoidable mortality
#   429  K292  Avoidable mortality
#   430  G060  causa não evitável
#   431  D571  causa não evitável
#   432  M198  causa não evitável
#   433  Q897  causa não evitável
#   434  X207  Avoidable mortality
#   435  X935  Avoidable mortality
#   436  O151  causa não evitável
#   437  Q000  Avoidable mortality
#   438  V285  Avoidable mortality
#   439  C880  causa não evitável
#   440  B91   causa não evitável
#   441  X610  Avoidable mortality
#   442  I428  causa não evitável
#   443  V645  Avoidable mortality
#   444  X718  Avoidable mortality
#   445  W708  Avoidable mortality
#   446  I441  causa não evitável
#   447  K529  causa não evitável
#   448  P229  Avoidable mortality
#   449  P582  Avoidable mortality
#   450  K519  causa não evitável
#   451  I339  causa não evitável
#   452  V099  Avoidable mortality
#   453  X730  Avoidable mortality
#   454  D469  causa não evitável
#   455  L089  causa não evitável
#   456  P251  Avoidable mortality
#   457  E870  causa não evitável
#   458  W130  Avoidable mortality
#   459  X740  Avoidable mortality
#   460  K659  causa não evitável
#   461  Q224  Avoidable mortality
#   462  E662  causa não evitável
#   463  X339  Avoidable mortality
#   464  W031  Avoidable mortality
#   465  P209  Avoidable mortality
#   466  K851  Avoidable mortality
#   467  B559  causa não evitável
#   468  Q031  causa não evitável
#   469  I620  Avoidable mortality
#   470  A483  causa não evitável
#   471  C749  causa não evitável
#   472  W780  Avoidable mortality
#   473  B570  causa não evitável
#   474  E763  causa não evitável
#   475  B220  Avoidable mortality
#   476  W870  Avoidable mortality
#   477  W178  Avoidable mortality
#   478  K562  causa não evitável
#   479  C163  Avoidable mortality
#   480  C851  causa não evitável
#   481  V494  Avoidable mortality
#   482  K222  causa não evitável
#   483  C37   causa não evitável
#   484  N499  causa não evitável
#   485  C798  causa não evitável
#   486  P248  Avoidable mortality
#   487  W190  Avoidable mortality
#   488  W784  Avoidable mortality
#   489  I139  Avoidable mortality
#   490  G936  causa não evitável
#   491  C187  causa não evitável
#   492  C220  Avoidable mortality
#   493  C889  causa não evitável
#   494  C119  causa não evitável
#   495  I429  causa não evitável
#   496  F329  causa não evitável
#   497  C419  causa não evitável
#   498  D65   causa não evitável
#   499  K660  causa não evitável
#   500  C211  causa não evitável
#   501  C929  causa não evitável
#   502  L031  causa não evitável
#   503  I409  causa não evitável
#   504  Q459  causa não evitável
#   505  I702  Avoidable mortality
#   506  N209  Avoidable mortality
#   507  N12   causa não evitável
#   508  C249  causa não evitável
#   509  V430  Avoidable mortality
#   510  Y008  Avoidable mortality
#   511  V229  Avoidable mortality
#   512  B210  Avoidable mortality
#   513  P968  Avoidable mortality
#   514  C698  causa não evitável
#   515  C218  causa não evitável
#   516  D689  causa não evitável
#   517  P369  Avoidable mortality
#   518  Y834  Avoidable mortality
#   519  N039  Avoidable mortality
#   520  Q613  causa não evitável
#   521  V486  Avoidable mortality
#   522  V124  Avoidable mortality
#   523  N289  causa não evitável
#   524  Q019  Avoidable mortality
#   525  P721  Avoidable mortality
#   526  P015  Avoidable mortality
#   527  W010  Avoidable mortality
#   528  V279  Avoidable mortality
#   529  Y268  Avoidable mortality
#   530  R64   causa não evitável
#   531  C763  causa não evitável
#   532  B589  causa não evitável
#   533  Q433  causa não evitável
#   534  I872  causa não evitável
#   535  O459  causa não evitável
#   536  K839  Avoidable mortality
#   537  A267  causa não evitável
#   538  K804  Avoidable mortality
#   539  X919  Avoidable mortality
#   540  W749  Avoidable mortality
#   541  W879  Avoidable mortality
#   542  Q336  causa não evitável
#   543  K460  Avoidable mortality
#   544  Y089  Avoidable mortality
#   545  X979  Avoidable mortality
#   546  X932  Avoidable mortality
#   547  X710  Avoidable mortality
#   548  M726  causa não evitável
#   549  Q259  Avoidable mortality
#   550  I741  causa não evitável
#   551  N178  Avoidable mortality
#   552  N61   causa não evitável
#   553  I248  Avoidable mortality
#   554  K37   Avoidable mortality
#   555  K359  Avoidable mortality
#   556  K632  causa não evitável
#   557  I629  Avoidable mortality
#   558  C819  Avoidable mortality
#   559  I342  causa não evitável
#   560  B227  Avoidable mortality
#   561  K298  causa não evitável
#   562  A169  Avoidable mortality
#   563  R100  causa não evitável
#   564  I211  Avoidable mortality
#   565  K701  Avoidable mortality
#   566  E780  causa não evitável
#   567  K858  Avoidable mortality
#   568  B189  Avoidable mortality
#   569  Y099  Avoidable mortality
#   570  J110  Avoidable mortality
#   571  D758  causa não evitável
#   572  Y000  Avoidable mortality
#   573  K528  causa não evitável
#   574  J384  Avoidable mortality
#   575  Y835  Avoidable mortality
#   576  B209  Avoidable mortality
#   577  B550  causa não evitável
#   578  K658  causa não evitável
#   579  O150  causa não evitável
#   580  D45   causa não evitável
#   581  C257  causa não evitável
#   582  E874  causa não evitável
#   583  I421  causa não evitável
#   584  I691  Avoidable mortality
#   585  C759  causa não evitável
#   586  G808  causa não evitável
#   587  W105  Avoidable mortality
#   588  X914  Avoidable mortality
#   589  G039  causa não evitável
#   590  P289  Avoidable mortality
#   591  B004  causa não evitável
#   592  G934  causa não evitável
#   593  G458  causa não evitável
#   594  G301  causa não evitável
#   595  D144  Avoidable mortality
#   596  W110  Avoidable mortality
#   597  W740  Avoidable mortality
#   598  I716  Avoidable mortality
#   599  Y044  Avoidable mortality
#   600  V204  Avoidable mortality
#   601  V274  Avoidable mortality
#   602  Q878  causa não evitável
#   603  M866  causa não evitável
#   604  C950  causa não evitável
#   605  A150  Avoidable mortality
#   606  G710  causa não evitável
#   607  K272  Avoidable mortality
#   608  I832  causa não evitável
#   609  D143  Avoidable mortality
#   610  J09   Avoidable mortality
#   611  C188  causa não evitável
#   612  C158  causa não evitável
#   613  G319  causa não evitável
#   614  L408  causa não evitável
#   615  I130  Avoidable mortality
#   616  C413  causa não evitável
#   617  N40   Avoidable mortality
#   618  G610  causa não evitável
#   619  C500  causa não evitável
#   620  I771  causa não evitável
#   621  K254  Avoidable mortality
#   622  Y342  Avoidable mortality
#   623  Q054  Avoidable mortality
#   624  A199  Avoidable mortality
#   625  C829  causa não evitável
#   626  B441  causa não evitável
#   627  B182  Avoidable mortality
#   628  C269  causa não evitável
#   629  V476  Avoidable mortality
#   630  G312  Avoidable mortality
#   631  F101  Avoidable mortality
#   632  G804  causa não evitável
#   633  W069  Avoidable mortality
#   634  Q258  Avoidable mortality
#   635  J22   Avoidable mortality
#   636  A160  Avoidable mortality
#   637  P398  Avoidable mortality
#   638  K047  causa não evitável
#   639  O266  causa não evitável
#   640  V685  Avoidable mortality
#   641  V99   Avoidable mortality
#   642  E668  causa não evitável
#   643  P285  Avoidable mortality
#   644  M728  causa não evitável
#   645  V874  Avoidable mortality
#   646  P072  Avoidable mortality
#   647  C328  causa não evitável
#   648  D410  causa não evitável
#   649  C185  causa não evitável
#   650  X420  Avoidable mortality
#   651  W459  Avoidable mortality
#   652  W192  Avoidable mortality
#   653  V444  Avoidable mortality
#   654  P77   Avoidable mortality
#   655  P200  Avoidable mortality
#   656  E840  causa não evitável
#   657  D180  Avoidable mortality
#   658  C384  causa não evitável
#   659  W450  Avoidable mortality
#   660  W790  Avoidable mortality
#   661  X780  Avoidable mortality
#   662  V149  Avoidable mortality
#   663  E101  Avoidable mortality
#   664  Q639  causa não evitável
#   665  P269  Avoidable mortality
#   666  I749  causa não evitável
#   667  E440  causa não evitável
#   668  K250  Avoidable mortality
#   669  A394  Avoidable mortality
#   670  X840  Avoidable mortality
#   671  W799  Avoidable mortality
#   672  V194  Avoidable mortality
#   673  B206  Avoidable mortality
#   674  C577  causa não evitável
#   675  R58   causa não evitável
#   676  G911  causa não evitável
#   677  P011  Avoidable mortality
#   678  K738  Avoidable mortality
#   679  K750  causa não evitável
#   680  M329  causa não evitável
#   681  Q250  Avoidable mortality
#   682  G300  causa não evitável
#   683  N300  causa não evitável
#   684  Y094  Avoidable mortality
#   685  E86   causa não evitável
#   686  K700  Avoidable mortality
#   687  C538  causa não evitável
#   688  V041  Avoidable mortality
#   689  K869  Avoidable mortality
#   690  W138  Avoidable mortality
#   691  B451  causa não evitável
#   692  Q203  Avoidable mortality
#   693  A047  Avoidable mortality
#   694  Y149  Avoidable mortality
#   695  B222  Avoidable mortality
#   696  I279  causa não evitável
#   697  X928  Avoidable mortality
#   698  X689  Avoidable mortality
#   699  K704  Avoidable mortality
#   700  C911  Avoidable mortality
#   701  F142  Avoidable mortality
#   702  R54   causa não evitável
#   703  C65   causa não evitável
#   704  V471  Avoidable mortality
#   705  D849  causa não evitável
#   706  X804  Avoidable mortality
#   707  V051  Avoidable mortality
#   708  X704  Avoidable mortality
#   709  W679  Avoidable mortality
#   710  E878  causa não evitável
#   711  Y209  Avoidable mortality
#   712  Y289  Avoidable mortality
#   713  I330  causa não evitável
#   714  N10   causa não evitável
#   715  C969  causa não evitável
#   716  C578  causa não evitável
#   717  Y850  causa não evitável
#   718  W198  Avoidable mortality
#   719  C712  causa não evitável
#   720  V784  Avoidable mortality
#   721  C921  causa não evitável
#   722  C762  causa não evitável
#   723  C729  causa não evitável
#   724  C839  causa não evitável
#   725  K350  Avoidable mortality
#   726  J46   Avoidable mortality
#   727  V677  Avoidable mortality
#   728  V675  Avoidable mortality
#   729  R571  causa não evitável
#   730  C436  Avoidable mortality
#   731  A049  Avoidable mortality
#   732  G931  causa não evitável
#   733  G473  causa não evitável
#   734  J158  Avoidable mortality
#   735  Q039  causa não evitável
#   736  F107  Avoidable mortality
#   737  G403  Avoidable mortality
#   738  I050  Avoidable mortality
#   739  Q999  causa não evitável
#   740  X745  Avoidable mortality
#   741  V485  Avoidable mortality
#   742  V225  Avoidable mortality
#   743  Y841  Avoidable mortality
#   744  C841  causa não evitável
#   745  C221  Avoidable mortality
#   746  P280  Avoidable mortality
#   747  A159  Avoidable mortality
#   748  X769  Avoidable mortality
#   749  I311  causa não evitável
#   750  E800  causa não evitável
#   751  J069  Avoidable mortality
#   752  R688  causa não evitável
#   753  Y294  Avoidable mortality
#   754  C310  causa não evitável
#   755  C437  Avoidable mortality
#   756  I718  Avoidable mortality
#   757  Y199  Avoidable mortality
#   758  B202  Avoidable mortality
#   759  I313  causa não evitável
#   760  P021  Avoidable mortality
#   761  Y348  Avoidable mortality
#   762  X612  Avoidable mortality
#   763  F99   causa não evitável
#   764  B374  causa não evitável
#   765  K803  Avoidable mortality
#   766  E106  Avoidable mortality
#   767  G373  causa não evitável
#   768  C320  causa não evitável
#   769  Y098  Avoidable mortality
#   770  P059  Avoidable mortality
#   771  X049  Avoidable mortality
#   772  B259  causa não evitável
#   773  W194  Avoidable mortality
#   774  Y579  Avoidable mortality
#   775  N498  causa não evitável
#   776  X429  Avoidable mortality
#   777  J851  Avoidable mortality
#   778  K909  causa não evitável
#   779  W188  Avoidable mortality
#   780  W840  Avoidable mortality
#   781  I011  Avoidable mortality
#   782  V922  Avoidable mortality
#   783  X337  Avoidable mortality
#   784  X090  Avoidable mortality
#   785  Q061  causa não evitável
#   786  E120  Avoidable mortality
#   787  C912  causa não evitável
#   788  I618  Avoidable mortality
#   789  K852  Avoidable mortality
#   790  W104  Avoidable mortality
#   791  X957  Avoidable mortality
#   792  Q229  Avoidable mortality
#   793  Q248  Avoidable mortality
#   794  K739  Avoidable mortality
#   795  V879  Avoidable mortality
#   796  K631  causa não evitável
#   797  V245  Avoidable mortality
#   798  A192  Avoidable mortality
#   799  I129  Avoidable mortality
#   800  F193  Avoidable mortality
#   801  V179  Avoidable mortality
#   802  K440  Avoidable mortality
#   803  V209  Avoidable mortality
#   804  K630  causa não evitável
#   805  R95   causa não evitável
#   806  V699  Avoidable mortality
#   807  Y208  Avoidable mortality
#   808  C750  causa não evitável
#   809  Y214  Avoidable mortality
#   810  J698  Avoidable mortality
#   811  I080  Avoidable mortality
#   812  D762  causa não evitável
#   813  I426  Avoidable mortality
#   814  I633  Avoidable mortality
#   815  C170  causa não evitável
#   816  V298  Avoidable mortality
#   817  W349  Avoidable mortality
#   818  K861  Avoidable mortality
#   819  F100  Avoidable mortality
#   820  C629  causa não evitável
#   821  D471  causa não evitável
#   822  B169  Avoidable mortality
#   823  I254  Avoidable mortality
#   824  V434  Avoidable mortality
#   825  E660  causa não evitável
#   826  A412  causa não evitável
#   827  X705  Avoidable mortality
#   828  C399  causa não evitável
#   829  C184  causa não evitável
#   830  E43   causa não evitável
#   831  X499  Avoidable mortality
#   832  K802  Avoidable mortality
#   833  D361  Avoidable mortality
#   834  X640  Avoidable mortality
#   835  P60   Avoidable mortality
#   836  I319  causa não evitável
#   837  D320  Avoidable mortality
#   838  Q210  Avoidable mortality
#   839  P619  Avoidable mortality
#   840  V799  Avoidable mortality
#   841  I728  causa não evitável
#   842  J060  Avoidable mortality
#   843  X334  Avoidable mortality
#   844  V294  Avoidable mortality
#   845  X742  Avoidable mortality
#   846  W139  Avoidable mortality
#   847  I601  Avoidable mortality
#   848  D464  causa não evitável
#   849  N151  causa não evitável
#   850  Q213  Avoidable mortality
#   851  I351  causa não evitável
#   852  C678  causa não evitável
#   853  B552  causa não evitável
#   854  C408  causa não evitável
#   855  X992  Avoidable mortality
#   856  B418  causa não evitável
#   857  N142  causa não evitável
#   858  I516  causa não evitável
#   859  N309  causa não evitável
#   860  O152  causa não evitável
#   861  K639  causa não evitável
#   862  K290  causa não evitável
#   863  I831  causa não evitável
#   864  Q201  Avoidable mortality
#   865  V280  Avoidable mortality
#   866  K404  Avoidable mortality
#   867  D570  causa não evitável
#   868  C049  causa não evitável
#   869  M819  causa não evitável
#   870  K251  Avoidable mortality
#   871  E778  causa não evitável
#   872  C793  causa não evitável
#   873  E042  Avoidable mortality
#   874  K284  Avoidable mortality
#   875  P035  Avoidable mortality
#   876  E116  Avoidable mortality
#   877  I698  Avoidable mortality
#   878  P293  Avoidable mortality
#   879  I090  Avoidable mortality
#   880  G379  causa não evitável
#   881  A310  causa não evitável
#   882  G939  causa não evitável
#   883  M319  causa não evitável
#   884  I442  causa não evitável
#   885  G009  causa não evitável
#   886  J448  Avoidable mortality
#   887  J939  Avoidable mortality
#   888  D696  causa não evitável
#   889  F171  causa não evitável
#   890  I692  Avoidable mortality
#   891  V196  Avoidable mortality
#   892  L984  causa não evitável
#   893  K650  causa não evitável
#   894  X800  Avoidable mortality
#   895  W108  Avoidable mortality
#   896  X910  Avoidable mortality
#   897  C751  causa não evitável
#   898  X615  Avoidable mortality
#   899  E441  causa não evitável
#   900  O995  causa não evitável
#   901  P023  Avoidable mortality
#   902  I738  causa não evitável
#   903  C342  Avoidable mortality
#   904  W147  Avoidable mortality
#   905  W179  Avoidable mortality
#   906  B250  causa não evitável
#   907  D869  causa não evitável
#   908  P228  Avoidable mortality
#   909  Q059  Avoidable mortality
#   910  X951  Avoidable mortality
#   911  I510  causa não evitável
#   912  D683  causa não evitável
#   913  P299  Avoidable mortality
#   914  Y248  Avoidable mortality
#   915  P960  Avoidable mortality
#   916  J168  Avoidable mortality
#   917  C951  causa não evitável
#   918  N281  causa não evitável
#   919  V888  Avoidable mortality
#   920  D021  causa não evitável
#   921  C403  causa não evitável
#   922  P569  Avoidable mortality
#   923  C720  causa não evitável
#   924  J709  Avoidable mortality
#   925  C444  causa não evitável
#   926  C068  causa não evitável
#   927  I131  Avoidable mortality
#   928  Y158  Avoidable mortality
#   929  D477  causa não evitável
#   930  P219  Avoidable mortality
#   931  K921  causa não evitável
#   932  V570  Avoidable mortality
#   933  E131  Avoidable mortality
#   934  P741  Avoidable mortality
#   935  V039  Avoidable mortality
#   936  K766  causa não evitável
#   937  Y005  Avoidable mortality
#   938  Q420  causa não evitável
#   939  Q917  causa não evitável
#   940  K565  causa não evitável
#   941  I081  Avoidable mortality
#   942  G002  causa não evitável
#   943  C438  Avoidable mortality
#   944  K299  causa não evitável
#   945  W205  Avoidable mortality
#   946  A279  causa não evitável
#   947  A168  Avoidable mortality
#   948  A99   causa não evitável
#   949  G231  causa não evitável
#   950  E40   causa não evitável
#   951  G249  causa não evitável
#   952  C788  causa não evitável
#   953  A390  Avoidable mortality
#   954  C761  causa não evitável
#   955  V871  Avoidable mortality
#   956  X859  Avoidable mortality
#   957  I349  causa não evitável
#   958  M069  causa não evitável
#   959  I359  causa não evitável
#   960  R568  causa não evitável
#   961  A179  Avoidable mortality
#   962  C154  causa não evitável
#   963  E872  causa não evitável
#   964  G459  causa não evitável
#   965  I674  Avoidable mortality
#   966  W014  Avoidable mortality
#   967  R229  causa não evitável
#   968  V949  Avoidable mortality
#   969  C227  Avoidable mortality
#   970  J869  Avoidable mortality
#   971  G308  causa não evitável
#   972  C579  causa não evitável
#   973  C837  causa não evitável
#   974  C258  causa não evitável
#   975  F319  causa não evitável
#   976  X701  Avoidable mortality
#   977  W874  Avoidable mortality
#   978  C241  causa não evitável
#   979  C767  causa não evitável
#   980  C519  causa não evitável
#   981  C343  Avoidable mortality
#   982  Y260  Avoidable mortality
#   983  F199  Avoidable mortality
#   984  C418  causa não evitável
#   985  X649  Avoidable mortality
#   986  W699  Avoidable mortality
#   987  C857  causa não evitável
#   988  Q771  causa não evitável
#   989  V295  Avoidable mortality
#   990  E102  Avoidable mortality
#   991  A810  causa não evitável
#   992  C102  causa não evitável
#   993  E111  Avoidable mortality
#   994  X619  Avoidable mortality
#   995  I613  Avoidable mortality
#   996  G588  causa não evitável
#   997  X909  Avoidable mortality
#   998  K629  causa não evitável
#   999  W877  Avoidable mortality
#  1000  C412  causa não evitável
#  1001  I719  Avoidable mortality
#  1002  E785  causa não evitável
#  1003  V142  Avoidable mortality
#  1004  J40   Avoidable mortality
#  1005  V870  Avoidable mortality
#  1006  A410  causa não evitável
#  1007  Q898  causa não evitável
#  1008  D479  causa não evitável
#  1009  C162  Avoidable mortality
#  1010  P020  Avoidable mortality
#  1011  V139  Avoidable mortality
#  1012  W809  Avoidable mortality
#  1013  Q257  Avoidable mortality
#  1014  Q043  causa não evitável
#  1015  I670  Avoidable mortality
#  1016  W760  Avoidable mortality
#  1017  D432  causa não evitável
#  1018  Y300  Avoidable mortality
#  1019  W744  Avoidable mortality
#  1020  W745  Avoidable mortality
#  1021  D376  causa não evitável
#  1022  W871  Avoidable mortality
#  1023  A219  causa não evitável
#  1024  C902  causa não evitável
#  1025  G969  causa não evitável
#  1026  D329  Avoidable mortality
#  1027  V845  Avoidable mortality
#  1028  K274  Avoidable mortality
#  1029  W789  Avoidable mortality
#  1030  R509  causa não evitável
#  1031  K860  Avoidable mortality
#  1032  D699  causa não evitável
#  1033  B574  causa não evitável
#  1034  K420  Avoidable mortality
#  1035  P239  Avoidable mortality
#  1036  E118  Avoidable mortality
#  1037  Y201  Avoidable mortality
#  1038  C785  causa não evitável
#  1039  V291  Avoidable mortality
#  1040  G932  causa não evitável
#  1041  Q246  Avoidable mortality
#  1042  B575  causa não evitável
#  1043  W120  Avoidable mortality
#  1044  P024  Avoidable mortality
#  1045  P003  Avoidable mortality
#  1046  P201  Avoidable mortality
#  1047  L028  causa não evitável
#  1048  J677  Avoidable mortality
#  1049  E162  causa não evitável
#  1050  I630  Avoidable mortality
#  1051  W175  Avoidable mortality
#  1052  C414  causa não evitável
#  1053  Q790  causa não evitável
#  1054  Y240  Avoidable mortality
#  1055  I715  Avoidable mortality
#  1056  D486  causa não evitável
#  1057  D374  causa não evitável
#  1058  W800  Avoidable mortality
#  1059  I089  Avoidable mortality
#  1060  E841  causa não evitável
#  1061  Q200  Avoidable mortality
#  1062  K808  Avoidable mortality
#  1063  D591  causa não evitável
#  1064  B171  Avoidable mortality
#  1065  O758  causa não evitável
#  1066  B659  causa não evitável
#  1067  I672  Avoidable mortality
#  1068  A191  Avoidable mortality
#  1069  I616  Avoidable mortality
#  1070  E137  Avoidable mortality
#  1071  K710  causa não evitável
#  1072  N219  Avoidable mortality
#  1073  K712  causa não evitável
#  1074  K509  causa não evitável
#  1075  A499  causa não evitável
#  1076  I270  causa não evitável
#  1077  V495  Avoidable mortality
#  1078  V546  Avoidable mortality
#  1079  I440  causa não evitável
#  1080  E889  causa não evitável
#  1081  I212  Avoidable mortality
#  1082  K590  causa não evitável
#  1083  C672  causa não evitável
#  1084  V819  Avoidable mortality
#  1085  C840  causa não evitável
#  1086  Q273  Avoidable mortality
#  1087  O989  causa não evitável
#  1088  I612  Avoidable mortality
#  1089  K759  causa não evitável
#  1090  P288  Avoidable mortality
#  1091  P351  Avoidable mortality
#  1092  I209  Avoidable mortality
#  1093  Q048  causa não evitável
#  1094  K259  Avoidable mortality
#  1095  I607  Avoidable mortality
#  1096  C771  causa não evitável
#  1097  K403  Avoidable mortality
#  1098  I632  Avoidable mortality
#  1099  J13   Avoidable mortality
#  1100  B199  Avoidable mortality
#  1101  N201  Avoidable mortality
#  1102  B218  Avoidable mortality
#  1103  Q018  Avoidable mortality
#  1104  N399  causa não evitável
#  1105  I679  Avoidable mortality
#  1106  R227  causa não evitável
#  1107  Y119  Avoidable mortality
#  1108  K929  causa não evitável
#  1109  I490  causa não evitável
#  1110  C248  causa não evitável
#  1111  E113  Avoidable mortality
#  1112  V958  Avoidable mortality
#  1113  Y449  Avoidable mortality
#  1114  J680  Avoidable mortality
#  1115  V804  Avoidable mortality
#  1116  V275  Avoidable mortality
#  1117  C838  causa não evitável
#  1118  M058  causa não evitável
#  1119  W338  Avoidable mortality
#  1120  W670  Avoidable mortality
#  1121  X690  Avoidable mortality
#  1122  X600  Avoidable mortality
#  1123  D509  Avoidable mortality
#  1124  F103  Avoidable mortality
#  1125  V496  Avoidable mortality
#  1126  C549  causa não evitável
#  1127  K285  Avoidable mortality
#  1128  K612  causa não evitável
#  1129  O85   causa não evitável
#  1130  J386  Avoidable mortality
#  1131  A502  Avoidable mortality
#  1132  Q794  causa não evitável
#  1133  R048  causa não evitável
#  1134  F200  causa não evitável
#  1135  L932  causa não evitável
#  1136  E104  Avoidable mortality
#  1137  M349  causa não evitável
#  1138  K469  Avoidable mortality
#  1139  X720  Avoidable mortality
#  1140  P261  Avoidable mortality
#  1141  X749  Avoidable mortality
#  1142  K461  Avoidable mortality
#  1143  K853  Avoidable mortality
#  1144  F259  causa não evitável
#  1145  K721  causa não evitável
#  1146  B238  Avoidable mortality
#  1147  G712  causa não evitável
#  1148  C689  causa não evitável
#  1149  V809  Avoidable mortality
#  1150  W497  Avoidable mortality
#  1151  V800  Avoidable mortality
#  1152  Q850  causa não evitável
#  1153  C602  causa não evitável
#  1154  Q349  causa não evitável
#  1155  I723  causa não evitável
#  1156  Q079  causa não evitável
#  1157  R101  causa não evitável
#  1158  C495  causa não evitável
#  1159  C301  causa não evitável
#  1160  B334  causa não evitável
#  1161  V296  Avoidable mortality
#  1162  V129  Avoidable mortality
#  1163  W134  Avoidable mortality
#  1164  B949  causa não evitável
#  1165  X490  Avoidable mortality
#  1166  Q899  causa não evitável
#  1167  V029  Avoidable mortality
#  1168  O231  causa não evitável
#  1169  F412  causa não evitável
#  1170  G609  causa não evitável
#  1171  B479  causa não evitável
#  1172  C435  Avoidable mortality
#  1173  Y040  Avoidable mortality
#  1174  C693  causa não evitável
#  1175  X794  Avoidable mortality
#  1176  V425  Avoidable mortality
#  1177  X995  Avoidable mortality
#  1178  P019  Avoidable mortality
#  1179  B377  causa não evitável
#  1180  J041  Avoidable mortality
#  1181  C150  causa não evitável
#  1182  R090  causa não evitável
#  1183  A308  causa não evitável
#  1184  Y332  Avoidable mortality
#  1185  X920  Avoidable mortality
#  1186  P271  Avoidable mortality
#  1187  X080  Avoidable mortality
#  1188  K513  causa não evitável
#  1189  Q234  Avoidable mortality
#  1190  O882  causa não evitável
#  1191  W299  Avoidable mortality
#  1192  C571  causa não evitável
#  1193  K720  causa não evitável
#  1194  F339  causa não evitável
#  1195  X729  Avoidable mortality
#  1196  C714  causa não evitável
#  1197  D020  causa não evitável
#  1198  I614  Avoidable mortality
#  1199  Y095  Avoidable mortality
#  1200  F419  causa não evitável
#  1201  I083  Avoidable mortality
#  1202  B018  Avoidable mortality
#  1203  C155  causa não evitável
#  1204  V020  Avoidable mortality
#  1205  V959  Avoidable mortality
#  1206  K430  Avoidable mortality
#  1207  P071  Avoidable mortality
#  1208  I610  Avoidable mortality
#  1209  E100  Avoidable mortality
#  1210  V184  Avoidable mortality
#  1211  K271  Avoidable mortality
#  1212  I709  Avoidable mortality
#  1213  Y309  Avoidable mortality
#  1214  W687  Avoidable mortality
#  1215  N719  Avoidable mortality
#  1216  L97   causa não evitável
#  1217  B162  Avoidable mortality
#  1218  X792  Avoidable mortality
#  1219  V903  Avoidable mortality
#  1220  X940  Avoidable mortality
#  1221  B212  Avoidable mortality
#  1222  E249  Avoidable mortality
#  1223  V575  Avoidable mortality
#  1224  F019  causa não evitável
#  1225  I602  Avoidable mortality
#  1226  V090  Avoidable mortality
#  1227  Y357  causa não evitável
#  1228  C688  causa não evitável
#  1229  I498  causa não evitável
#  1230  W200  Avoidable mortality
#  1231  Y298  Avoidable mortality
#  1232  D352  Avoidable mortality
#  1233  N921  causa não evitável
#  1234  D127  Avoidable mortality
#  1235  I615  Avoidable mortality
#  1236  G825  causa não evitável
#  1237  Q226  Avoidable mortality
#  1238  Y831  Avoidable mortality
#  1239  V649  Avoidable mortality
#  1240  M729  causa não evitável
#  1241  W390  Avoidable mortality
#  1242  W185  Avoidable mortality
#  1243  P050  Avoidable mortality
#  1244  E880  causa não evitável
#  1245  Q225  Avoidable mortality
#  1246  C009  causa não evitável
#  1247  X805  Avoidable mortality
#  1248  X469  Avoidable mortality
#  1249  M311  causa não evitável
#  1250  I724  causa não evitável
#  1251  I878  causa não evitável
#  1252  C915  causa não evitável
#  1253  I879  causa não evitável
#  1254  W374  Avoidable mortality
#  1255  G118  causa não evitável
#  1256  P008  Avoidable mortality
#  1257  X938  Avoidable mortality
#  1258  C430  Avoidable mortality
#  1259  C52   causa não evitável
#  1260  C398  causa não evitável
#  1261  I603  Avoidable mortality
#  1262  F141  Avoidable mortality
#  1263  C723  causa não evitável
#  1264  X819  Avoidable mortality
#  1265  I472  causa não evitável
#  1266  I720  causa não evitável
#  1267  I99   causa não evitável
#  1268  X764  Avoidable mortality
#  1269  J218  Avoidable mortality
#  1270  W782  Avoidable mortality
#  1271  D001  causa não evitável
#  1272  P559  Avoidable mortality
#  1273  P399  Avoidable mortality
#  1274  B052  Avoidable mortality
#  1275  Y264  Avoidable mortality
#  1276  I200  Avoidable mortality
#  1277  G040  causa não evitável
#  1278  D383  causa não evitável
#  1279  Q282  Avoidable mortality
#  1280  D259  Avoidable mortality
#  1281  O860  causa não evitável
#  1282  J039  Avoidable mortality
#  1283  V219  Avoidable mortality
#  1284  V682  Avoidable mortality
#  1285  X862  Avoidable mortality
#  1286  Y190  Avoidable mortality
#  1287  E871  causa não evitável
#  1288  P038  Avoidable mortality
#  1289  K560  causa não evitável
#  1290  W764  Avoidable mortality
#  1291  Q251  Avoidable mortality
#  1292  C062  causa não evitável
#  1293  G800  causa não evitável
#  1294  Q602  causa não evitável
#  1295  K702  Avoidable mortality
#  1296  W743  Avoidable mortality
#  1297  Q070  causa não evitável
#  1298  V429  Avoidable mortality
#  1299  C66   causa não evitável
#  1300  C765  causa não evitável
#  1301  L033  causa não evitável
#  1302  W878  Avoidable mortality
#  1303  W848  Avoidable mortality
#  1304  X089  Avoidable mortality
#  1305  N288  causa não evitável
#  1306  G310  causa não evitável
#  1307  A985  causa não evitável
#  1308  G822  causa não evitável
#  1309  M310  causa não evitável
#  1310  L038  causa não evitável
#  1311  Q042  causa não evitável
#  1312  V180  Avoidable mortality
#  1313  K275  Avoidable mortality
#  1314  K928  causa não evitável
#  1315  Y280  Avoidable mortality
#  1316  X399  Avoidable mortality
#  1317  Y883  causa não evitável
#  1318  Q430  causa não evitável
#  1319  I019  Avoidable mortality
#  1320  Y339  Avoidable mortality
#  1321  N926  causa não evitável
#  1322  X620  Avoidable mortality
#  1323  N811  causa não evitável
#  1324  B59   causa não evitável
#  1325  J120  Avoidable mortality
#  1326  B410  causa não evitável
#  1327  C300  causa não evitável
#  1328  I214  Avoidable mortality
#  1329  C631  causa não evitável
#  1330  F104  Avoidable mortality
#  1331  V199  Avoidable mortality
#  1332  C402  causa não evitável
#  1333  K831  Avoidable mortality
#  1334  C222  Avoidable mortality
#  1335  W690  Avoidable mortality
#  1336  N768  causa não evitável
#  1337  I495  causa não evitável
#  1338  K311  causa não evitável
#  1339  K421  Avoidable mortality
#  1340  G311  causa não evitável
#  1341  M089  causa não evitável
#  1342  C409  causa não evitável
#  1343  Q321  causa não evitável
#  1344  K564  causa não evitável
#  1345  C786  causa não evitável
#  1346  K252  Avoidable mortality
#  1347  V865  Avoidable mortality
#  1348  O441  causa não evitável
#  1349  P524  Avoidable mortality
#  1350  Q743  causa não evitável
#  1351  W678  Avoidable mortality
#  1352  K805  Avoidable mortality
#  1353  I740  causa não evitável
#  1354  G001  Avoidable mortality
#  1355  W149  Avoidable mortality
#  1356  C181  causa não evitável
#  1357  I631  Avoidable mortality
#  1358  G603  causa não evitável
#  1359  K559  causa não evitável
#  1360  C100  causa não evitável
#  1361  K269  Avoidable mortality
#  1362  C479  causa não evitável
#  1363  J989  causa não evitável
#  1364  J961  causa não evitável
#  1365  X699  Avoidable mortality
#  1366  X688  Avoidable mortality
#  1367  D447  causa não evitável
#  1368  V855  Avoidable mortality
#  1369  X944  Avoidable mortality
#  1370  F192  Avoidable mortality
#  1371  R579  causa não evitável
#  1372  O994  causa não evitável
#  1373  W439  Avoidable mortality
#  1374  W672  Avoidable mortality
#  1375  G912  causa não evitável
#  1376  C795  causa não evitável
#  1377  F83   causa não evitável
#  1378  V636  Avoidable mortality
#  1379  V639  Avoidable mortality
#  1380  X917  Avoidable mortality
#  1381  W140  Avoidable mortality
#  1382  J860  Avoidable mortality
#  1383  X949  Avoidable mortality
#  1384  C099  causa não evitável
#  1385  I513  causa não evitável
#  1386  I803  Avoidable mortality
#  1387  X974  Avoidable mortality
#  1388  X237  Avoidable mortality
#  1389  C341  Avoidable mortality
#  1390  B948  causa não evitável
#  1391  N171  Avoidable mortality
#  1392  B651  causa não evitável
#  1393  P298  Avoidable mortality
#  1394  W750  Avoidable mortality
#  1395  C160  Avoidable mortality
#  1396  Y442  Avoidable mortality
#  1397  K270  Avoidable mortality
#  1398  W133  Avoidable mortality
#  1399  I635  Avoidable mortality
#  1400  R072  causa não evitável
#  1401  E888  causa não evitável
#  1402  J980  causa não evitável
#  1403  O996  causa não evitável
#  1404  J100  Avoidable mortality
#  1405  C504  causa não evitável
#  1406  W193  Avoidable mortality
#  1407  C97   causa não evitável
#  1408  V283  Avoidable mortality
#  1409  V545  Avoidable mortality
#  1410  E748  causa não evitável
#  1411  G909  causa não evitável
#  1412  Y345  Avoidable mortality
#  1413  O065  Avoidable mortality
#  1414  I272  causa não evitável
#  1415  X238  Avoidable mortality
#  1416  Q622  causa não evitável
#  1417  X849  Avoidable mortality
#  1418  W317  Avoidable mortality
#  1419  X659  Avoidable mortality
#  1420  X489  Avoidable mortality
#  1421  E875  causa não evitável
#  1422  P618  Avoidable mortality
#  1423  G910  causa não evitável
#  1424  D589  causa não evitável
#  1425  J392  Avoidable mortality
#  1426  I634  Avoidable mortality
#  1427  E750  causa não evitável
#  1428  V877  Avoidable mortality
#  1429  A167  Avoidable mortality
#  1430  Q262  Avoidable mortality
#  1431  G10   causa não evitável
#  1432  E752  causa não evitável
#  1433  N329  causa não evitável
#  1434  E211  causa não evitável
#  1435  N009  Avoidable mortality
#  1436  C164  Avoidable mortality
#  1437  M348  causa não evitável
#  1438  V878  Avoidable mortality
#  1439  V491  Avoidable mortality
#  1440  J985  causa não evitável
#  1441  W170  Avoidable mortality
#  1442  P031  Avoidable mortality
#  1443  C059  causa não evitável
#  1444  P371  Avoidable mortality
#  1445  I778  causa não evitável
#  1446  Y832  Avoidable mortality
#  1447  Y284  Avoidable mortality
#  1448  H669  causa não evitável
#  1449  Y290  Avoidable mortality
#  1450  C400  causa não evitável
#  1451  X040  Avoidable mortality
#  1452  C210  causa não evitável
#  1453  M462  causa não evitável
#  1454  Q894  causa não evitável
#  1455  K409  Avoidable mortality
#  1456  B029  causa não evitável
#  1457  K265  Avoidable mortality
#  1458  Q858  causa não evitável
#  1459  C252  causa não evitável
#  1460  V599  Avoidable mortality
#  1461  L219  causa não evitável
#  1462  Q442  causa não evitável
#  1463  L512  causa não evitável
#  1464  F149  Avoidable mortality
#  1465  J42   Avoidable mortality
#  1466  I744  causa não evitável
#  1467  D377  causa não evitável
#  1468  D380  causa não evitável
#  1469  D70   causa não evitável
#  1470  C180  causa não evitável
#  1471  K221  causa não evitável
#  1472  N304  causa não evitável
# ...
# 11405  A039  Avoidable mortality
# 11406  B09   causa não evitável
# 11407  W225  Avoidable mortality
# 11408  A081  Avoidable mortality
# 11409  J432  Avoidable mortality
# 11410  J030  Avoidable mortality
# 11411  W863  Avoidable mortality
# 11412  W300  Avoidable mortality
# 11413  P230  Avoidable mortality
# 11414  F220  causa não evitável
# 11415  V159  Avoidable mortality
# 11416  Y654  Avoidable mortality
# 11417  K621  causa não evitável
# 11418  C505  causa não evitável
# 11419  Y139  Avoidable mortality
# 11420  Q375  causa não evitável
# 11421  Y128  Avoidable mortality
# 11422  G231  causa não evitável
# 11423  B500  Avoidable mortality
# 11424  V726  Avoidable mortality
# 11425  C061  causa não evitável
# 11426  X648  Avoidable mortality
# 11427  G819  causa não evitável
# 11428  X494  Avoidable mortality
# 11429  O670  causa não evitável
# 11430  R160  causa não evitável
# 11431  V420  Avoidable mortality
# 11432  X605  Avoidable mortality
# 11433  V917  Avoidable mortality
# 11434  D751  causa não evitável
# 11435  V259  Avoidable mortality
# 11436  P111  Avoidable mortality
# 11437  E222  causa não evitável
# 11438  V735  Avoidable mortality
# 11439  Q340  causa não evitável
# 11440  V579  Avoidable mortality
# 11441  X498  Avoidable mortality
# 11442  M532  causa não evitável
# 11443  B580  causa não evitável
# 11444  Q408  causa não evitável
# 11445  W830  Avoidable mortality
# 11446  V404  Avoidable mortality
# 11447  Y267  Avoidable mortality
# 11448  X735  Avoidable mortality
# 11449  Y125  Avoidable mortality
# 11450  X234  Avoidable mortality
# 11451  W735  Avoidable mortality
# 11452  O239  causa não evitável
# 11453  V324  Avoidable mortality
# 11454  X623  Avoidable mortality
# 11455  V953  Avoidable mortality
# 11456  V734  Avoidable mortality
# 11457  W705  Avoidable mortality
# 11458  G439  causa não evitável
# 11459  V589  Avoidable mortality
# 11460  Y239  Avoidable mortality
# 11461  J153  Avoidable mortality
# 11462  V542  Avoidable mortality
# 11463  W274  Avoidable mortality
# 11464  A960  causa não evitável
# 11465  W127  Avoidable mortality
# 11466  M998  causa não evitável
# 11467  Q386  causa não evitável
# 11468  E561  causa não evitável
# 11469  W847  Avoidable mortality
# 11470  W227  Avoidable mortality
# 11471  P558  Avoidable mortality
# 11472  X278  Avoidable mortality
# 11473  E779  causa não evitável
# 11474  V243  Avoidable mortality
# 11475  W991  Avoidable mortality
# 11476  G239  causa não evitável
# 11477  D803  causa não evitável
# 11478  C008  causa não evitável
# 11479  C681  causa não evitável
# 11480  M993  causa não evitável
# 11481  E011  Avoidable mortality
# 11482  P542  Avoidable mortality
# 11483  D34   Avoidable mortality
# 11484  W551  Avoidable mortality
# 11485  O011  Avoidable mortality
# 11486  W082  Avoidable mortality
# 11487  X441  Avoidable mortality
# 11488  Q643  causa não evitável
# 11489  M721  causa não evitável
# 11490  W643  Avoidable mortality
# 11491  E210  causa não evitável
# 11492  F146  Avoidable mortality
# 11493  E700  causa não evitável
# 11494  Q748  causa não evitável
# 11495  F189  Avoidable mortality
# 11496  A171  Avoidable mortality
# 11497  F400  causa não evitável
# 11498  O050  Avoidable mortality
# 11499  F412  causa não evitável
# 11500  X423  Avoidable mortality
# 11501  W095  Avoidable mortality
# 11502  W773  Avoidable mortality
# 11503  W337  Avoidable mortality
# 11504  P925  Avoidable mortality
# 11505  B487  causa não evitável
# 11506  Y590  Avoidable mortality
# 11507  P708  Avoidable mortality
# 11508  E511  causa não evitável
# 11509  Q712  causa não evitável
# 11510  P080  Avoidable mortality
# 11511  X488  Avoidable mortality
# 11512  N833  causa não evitável
# 11513  W261  Avoidable mortality
# 11514  M128  causa não evitável
# 11515  R309  causa não evitável
# 11516  E755  causa não evitável
# 11517  Y400  Avoidable mortality
# 11518  N824  causa não evitável
# 11519  X333  Avoidable mortality
# 11520  X204  Avoidable mortality
# 11521  X487  Avoidable mortality
# 11522  B161  Avoidable mortality
# 11523  O746  causa não evitável
# 11524  V921  Avoidable mortality
# 11525  D558  causa não evitável
# 11526  P928  Avoidable mortality
# 11527  Q355  causa não evitável
# 11528  A408  causa não evitável
# 11529  D441  causa não evitável
# 11530  W203  Avoidable mortality
# 11531  W298  Avoidable mortality
# 11532  D367  Avoidable mortality
# 11533  W325  Avoidable mortality
# 11534  W122  Avoidable mortality
# 11535  E248  Avoidable mortality
# 11536  P613  Avoidable mortality
# 11537  W268  Avoidable mortality
# 11538  V739  Avoidable mortality
# 11539  V143  Avoidable mortality
# 11540  P505  Avoidable mortality
# 11541  X093  Avoidable mortality
# 11542  D067  causa não evitável
# 11543  H728  causa não evitável
# 11544  N171  Avoidable mortality
# 11545  E560  causa não evitável
# 11546  O743  causa não evitável
# 11547  O758  causa não evitável
# 11548  C224  Avoidable mortality
# 11549  F669  causa não evitável
# 11550  N141  causa não evitável
# 11551  X460  Avoidable mortality
# 11552  Y234  Avoidable mortality
# 11553  J120  Avoidable mortality
# 11554  V832  Avoidable mortality
# 11555  O067  Avoidable mortality
# 11556  V609  Avoidable mortality
# 11557  P589  Avoidable mortality
# 11558  V922  Avoidable mortality
# 11559  X783  Avoidable mortality
# 11560  R261  causa não evitável
# 11561  D434  causa não evitável
# 11562  J704  Avoidable mortality
# 11563  N819  causa não evitável
# 11564  H720  causa não evitável
# 11565  Q610  causa não evitável
# 11566  E42   causa não evitável
# 11567  E270  Avoidable mortality
# 11568  W288  Avoidable mortality
# 11569  B083  causa não evitável
# 11570  B529  Avoidable mortality
# 11571  V942  Avoidable mortality
# 11572  Y880  causa não evitável
# 11573  Y038  Avoidable mortality
# 11574  W399  Avoidable mortality
# 11575  C695  causa não evitável
# 11576  A880  causa não evitável
# 11577  E02   Avoidable mortality
# 11578  X270  Avoidable mortality
# 11579  I844  causa não evitável
# 11580  W514  Avoidable mortality
# 11581  I845  causa não evitável
# 11582  N342  causa não evitável
# 11583  A401  causa não evitável
# 11584  V315  Avoidable mortality
# 11585  Y352  causa não evitável
# 11586  O419  causa não evitável
# 11587  Y043  Avoidable mortality
# 11588  L048  causa não evitável
# 11589  N391  causa não evitável
# 11590  Y157  Avoidable mortality
# 11591  V881  Avoidable mortality
# 11592  W507  Avoidable mortality
# 11593  F453  causa não evitável
# 11594  X847  Avoidable mortality
# 11595  G961  causa não evitável
# 11596  B64   causa não evitável
# 11597  C811  Avoidable mortality
# 11598  Q360  causa não evitável
# 11599  V939  Avoidable mortality
# 11600  D399  causa não evitável
# 11601  Q010  Avoidable mortality
# 11602  X822  Avoidable mortality
# 11603  Y220  Avoidable mortality
# 11604  C463  causa não evitável
# 11605  W256  Avoidable mortality
# 11606  R682  causa não evitável
# 11607  L950  causa não evitável
# 11608  P129  Avoidable mortality
# 11609  W802  Avoidable mortality
# 11610  N038  Avoidable mortality
# 11611  O629  causa não evitável
# 11612  G833  causa não evitável
# 11613  B569  causa não evitável
# 11614  Y168  Avoidable mortality
# 11615  C774  causa não evitável
# 11616  F55   causa não evitável
# 11617  D013  causa não evitável
# 11618  C752  causa não evitável
# 11619  O749  causa não evitável
# 11620  X292  Avoidable mortality
# 11621  L049  causa não evitável
# 11622  O429  causa não evitável
# 11623  R292  causa não evitável
# 11624  J348  Avoidable mortality
# 11625  D449  causa não evitável
# 11626  P835  Avoidable mortality
# 11627  V191  Avoidable mortality
# 11628  A666  causa não evitável
# 11629  Q372  causa não evitável
# 11630  N144  causa não evitável
# 11631  Y027  Avoidable mortality
# 11632  V507  Avoidable mortality
# 11633  C003  causa não evitável
# 11634  O223  causa não evitável
# 11635  V529  Avoidable mortality
# 11636  I159  Avoidable mortality
# 11637  Q281  Avoidable mortality
# 11638  X836  Avoidable mortality
# 11639  A070  Avoidable mortality
# 11640  Q242  Avoidable mortality
# 11641  D050  causa não evitável
# 11642  K314  causa não evitável
# 11643  A260  causa não evitável
# 11644  F203  causa não evitável
# 11645  E065  Avoidable mortality
# 11646  P800  Avoidable mortality
# 11647  V571  Avoidable mortality
# 11648  L402  causa não evitável
# 11649  O367  causa não evitável
# 11650  W838  Avoidable mortality
# 11651  V621  Avoidable mortality
# 11652  V773  Avoidable mortality
# 11653  D360  Avoidable mortality
# 11654  F233  causa não evitável
# 11655  W752  Avoidable mortality
# 11656  D818  causa não evitável
# 11657  O120  causa não evitável
# 11658  C638  causa não evitável
# 11659  P720  Avoidable mortality
# 11660  X746  Avoidable mortality
# 11661  D528  Avoidable mortality
# 11662  D072  causa não evitável
# 11663  F311  causa não evitável
# 11664  F21   causa não evitável
# 11665  J371  Avoidable mortality
# 11666  K824  Avoidable mortality
# 11667  F448  causa não evitável
# 11668  O891  causa não evitável
# 11669  X632  Avoidable mortality
# 11670  I360  causa não evitável
# 11671  F511  causa não evitável
# 11672  F800  causa não evitável
# 11673  Q044  causa não evitável
# 11674  X043  Avoidable mortality
# 11675  A829  causa não evitável
# 11676  Q380  causa não evitável
# 11677  D819  causa não evitável
# 11678  J674  Avoidable mortality
# 11679  Y020  Avoidable mortality
# 11680  W154  Avoidable mortality
# 11681  V133  Avoidable mortality
# 11682  X884  Avoidable mortality
# 11683  V887  Avoidable mortality
# 11684  V354  Avoidable mortality
# 11685  Q821  causa não evitável
# 11686  N820  causa não evitável
# 11687  Y021  Avoidable mortality
# 11688  V590  Avoidable mortality
# 11689  X405  Avoidable mortality
# 11690  N422  causa não evitável
# 11691  L959  causa não evitável
# 11692  Q660  causa não evitável
# 11693  B901  Avoidable mortality
# 11694  V811  Avoidable mortality
# 11695  O695  causa não evitável
# 11696  P808  Avoidable mortality
# 11697  A369  Avoidable mortality
# 11698  M601  causa não evitável
# 11699  F509  causa não evitável
# 11700  K299  causa não evitável
# 11701  C698  causa não evitável
# 11702  P598  Avoidable mortality
# 11703  A850  causa não evitável
# 11704  O742  causa não evitável
# 11705  Y792  Avoidable mortality
# 11706  V583  Avoidable mortality
# 11707  V390  Avoidable mortality
# 11708  P920  Avoidable mortality
# 11709  A066  Avoidable mortality
# 11710  F062  causa não evitável
# 11711  P154  Avoidable mortality
# 11712  A779  causa não evitável
# 11713  E018  Avoidable mortality
# 11714  F206  causa não evitável
# 11715  V421  Avoidable mortality
# 11716  X615  Avoidable mortality
# 11717  F710  causa não evitável
# 11718  C318  causa não evitável
# 11719  F314  causa não evitável
# 11720  G248  causa não evitável
# 11721  E611  causa não evitável
# 11722  I773  causa não evitável
# 11723  X010  Avoidable mortality
# 11724  J382  Avoidable mortality
# 11725  W660  Avoidable mortality
# 11726  N053  Avoidable mortality
# 11727  X019  Avoidable mortality
# 11728  V755  Avoidable mortality
# 11729  N62   causa não evitável
# 11730  N800  causa não evitável
# 11731  P719  Avoidable mortality
# 11732  C940  causa não evitável
# 11733  X319  Avoidable mortality
# 11734  Y482  Avoidable mortality
# 11735  W297  Avoidable mortality
# 11736  J418  Avoidable mortality
# 11737  K613  causa não evitável
# 11738  Q160  causa não evitável
# 11739  N304  causa não evitável
# 11740  V370  Avoidable mortality
# 11741  W051  Avoidable mortality
# 11742  Y455  Avoidable mortality
# 11743  C098  causa não evitável
# 11744  A520  Avoidable mortality
# 11745  C000  causa não evitável
# 11746  B068  Avoidable mortality
# 11747  W098  Avoidable mortality
# 11748  X030  Avoidable mortality
# 11749  I870  causa não evitável
# 11750  M154  causa não evitável
# 11751  N710  Avoidable mortality
# 11752  V807  Avoidable mortality
# 11753  V908  Avoidable mortality
# 11754  P364  Avoidable mortality
# 11755  W547  Avoidable mortality
# 11756  V437  Avoidable mortality
# 11757  Y279  Avoidable mortality
# 11758  N830  causa não evitável
# 11759  X810  Avoidable mortality
# 11760  F701  causa não evitável
# 11761  Y259  Avoidable mortality
# 11762  W242  Avoidable mortality
# 11763  V624  Avoidable mortality
# 11764  N948  causa não evitável
# 11765  V606  Avoidable mortality
# 11766  W187  Avoidable mortality
# 11767  H578  causa não evitável
# 11768  A689  causa não evitável
# 11769  V805  Avoidable mortality
# 11770  Q378  causa não evitável
# 11771  J351  Avoidable mortality
# 11772  Y335  Avoidable mortality
# 11773  H540  causa não evitável
# 11774  F849  causa não evitável
# 11775  W675  Avoidable mortality
# 11776  G211  causa não evitável
# 11777  V123  Avoidable mortality
# 11778  X622  Avoidable mortality
# 11779  P232  Avoidable mortality
# 11780  W943  Avoidable mortality
# 11781  W377  Avoidable mortality
# 11782  N848  causa não evitável
# 11783  B873  causa não evitável
# 11784  X462  Avoidable mortality
# 11785  D681  causa não evitável
# 11786  X902  Avoidable mortality
# 11787  Y845  Avoidable mortality
# 11788  A414  causa não evitável
# 11789  W167  Avoidable mortality
# 11790  V853  Avoidable mortality
# 11791  V673  Avoidable mortality
# 11792  D812  causa não evitável
# 11793  Y556  Avoidable mortality
# 11794  W118  Avoidable mortality
# 11795  Q527  causa não evitável
# 11796  O235  causa não evitável
# 11797  M438  causa não evitável
# 11798  E078  Avoidable mortality
# 11799  X878  Avoidable mortality
# 11800  V465  Avoidable mortality
# 11801  O468  causa não evitável
# 11802  W050  Avoidable mortality
# 11803  O079  Avoidable mortality
# 11804  X028  Avoidable mortality
# 11805  Q839  causa não evitável
# 11806  W846  Avoidable mortality
# 11807  X170  Avoidable mortality
# 11808  N134  Avoidable mortality
# 11809  O662  causa não evitável
# 11810  C512  causa não evitável
# 11811  X901  Avoidable mortality
# 11812  A429  causa não evitável
# 11813  X259  Avoidable mortality
# 11814  Y237  Avoidable mortality
# 11815  Y828  Avoidable mortality
# 11816  N835  causa não evitável
# 11817  W327  Avoidable mortality
# 11818  X370  Avoidable mortality
# 11819  X376  Avoidable mortality
# 11820  V952  Avoidable mortality
# 11821  F402  causa não evitável
# 11822  C004  causa não evitável
# 11823  D229  Avoidable mortality
# 11824  F145  Avoidable mortality
# 11825  D212  Avoidable mortality
# 11826  X852  Avoidable mortality
# 11827  B663  causa não evitável
# 11828  R010  causa não evitável
# 11829  O209  causa não evitável
# 11830  V103  Avoidable mortality
# 11831  N172  Avoidable mortality
# 11832  A920  causa não evitável
# 11833  Y062  Avoidable mortality
# 11834  G587  causa não evitável
# 11835  O229  causa não evitável
# 11836  D023  causa não evitável
# 11837  W331  Avoidable mortality
# 11838  V637  Avoidable mortality
# 11839  W090  Avoidable mortality
# 11840  X468  Avoidable mortality
# 11841  V933  Avoidable mortality
# 11842  I951  causa não evitável
# 11843  P518  Avoidable mortality
# 11844  V273  Avoidable mortality
# 11845  X738  Avoidable mortality
# 11846  W657  Avoidable mortality
# 11847  W017  Avoidable mortality
# 11848  V416  Avoidable mortality
# 11849  E053  Avoidable mortality
# 11850  P929  Avoidable mortality
# 11851  X294  Avoidable mortality
# 11852  A568  Avoidable mortality
# 11853  A230  causa não evitável
# 11854  W034  Avoidable mortality
# 11855  F440  causa não evitável
# 11856  P93   Avoidable mortality
# 11857  F459  causa não evitável
# 11858  V265  Avoidable mortality
# 11859  F229  causa não evitável
# 11860  I774  causa não evitável
# 11861  L500  causa não evitável
# 11862  K294  causa não evitável
# 11863  N251  Avoidable mortality
# 11864  M799  causa não evitável
# 11865  M174  causa não evitável
# 11866  V547  Avoidable mortality
# 11867  N814  causa não evitável
# 11868  P839  Avoidable mortality
# 11869  B340  causa não evitável
# 11870  N851  causa não evitável
# 11871  N641  causa não evitável
# 11872  A609  Avoidable mortality
# 11873  Q383  causa não evitável
# 11874  N312  causa não evitável
# 11875  X678  Avoidable mortality
# 11876  O862  causa não evitável
# 11877  O430  causa não evitável
# 11878  V900  Avoidable mortality
# 11879  Q403  causa não evitável
# 11880  W513  Avoidable mortality
# 11881  A590  Avoidable mortality
# 11882  A599  Avoidable mortality
# 11883  B870  causa não evitável
# 11884  O035  Avoidable mortality
# 11885  W519  Avoidable mortality
# 11886  R413  causa não evitável
# 11887  Q930  causa não evitável
# 11888  G543  causa não evitável
# 11889  X469  Avoidable mortality
# 11890  W041  Avoidable mortality
# 11891  V155  Avoidable mortality
# 11892  R456  causa não evitável
# 11893  L303  causa não evitável
# 11894  D040  causa não evitável
# -----  ----  -------------------

# %%
# Merge dobr_merged_pop_clean and df_a by CAUSABAS
dobr_evit_merged_temp01 = pd.merge(dobr_evit_merged_temp, df_a, on='CAUSABAS', how='left')

# mostrar dados gerais da tabela após transformações
tab = dobr_evit_merged_temp01
print(f'Registro da tabela : {tab.shape[0]}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 4446922
# +----+------------+-------------+-------------+---------------------+
# |    | CAUSABAS   | CODMUNRES   | ANO_OBITO   | classificacao       |
# |----+------------+-------------+-------------+---------------------|
# |  0 | I219       | _292740     | _2019       | Avoidable mortality |
# |  1 | I10        | _355100     | _2019       | Avoidable mortality |
# |  2 | X700       | _500630     | _2019       | Avoidable mortality |
# |  3 | C539       | _500500     | _2019       | causa não evitável  |
# |  4 | V220       | _500627     | _2019       | Avoidable mortality |
# +----+------------+-------------+-------------+---------------------+

# %%
# Mostrar resultados de classificacao
dobr_evit_merged_temp01.groupby('classificacao').count()
# Out:
#                      CAUSABAS  CODMUNRES  ANO_OBITO
# classificacao
# Avoidable mortality   2537888    2537888    2537888
# causa não evitável    1909034    1909034    1909034

# %%
# Manter na base só dados de CID evitáveis
dobr_evit_merged_temp02 = dobr_evit_merged_temp01[dobr_evit_merged_temp01['classificacao']=='Avoidable mortality']

# mostrar dados gerais da tabela após transformações
tab = dobr_evit_merged_temp02
print(f'Registro da tabela : {tab.shape[0]}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 2537888
# +----+------------+-------------+-------------+---------------------+
# |    | CAUSABAS   | CODMUNRES   | ANO_OBITO   | classificacao       |
# |----+------------+-------------+-------------+---------------------|
# |  0 | I219       | _292740     | _2019       | Avoidable mortality |
# |  1 | I10        | _355100     | _2019       | Avoidable mortality |
# |  2 | X700       | _500630     | _2019       | Avoidable mortality |
# |  4 | V220       | _500627     | _2019       | Avoidable mortality |
# |  5 | W019       | _500325     | _2019       | Avoidable mortality |
# +----+------------+-------------+-------------+---------------------+

# %% [markdown]
# #### Resultados do merge de cid_avoid e dobr

# %%
# Salvar arquivo final de DOBR
dobr_evit_merged_temp02.to_parquet('files_clean/dobr_evit_merged_v2.parquet')

# %%
# Contador

shape_origin = dobr_evit_merged_temp.CAUSABAS.count()
shape_filt = dobr_evit_merged_temp02.CAUSABAS.count()
dif = shape_origin - shape_filt


print_y(f" O número de óbitos após a limpeza e que constituía a base de dados de DO era de {shape_origin} óbitos ")
print_y(f" O número de registros excluídos por apresentar CIDs NÃO EVITÁVEIS foi de {dif} óbitos ")
print_y(f" O número de óbitos por CID EVITÁVEIS é de {shape_filt} óbitos ")
# Out:
#  ==>  O número de óbitos após a limpeza e que constituía a base de dados de DO era de 4446922 óbitos
#  ==>  O número de registros excluídos por apresentar CIDs NÃO EVITÁVEIS foi de 1909034 óbitos
#  ==>  O número de óbitos por CID EVITÁVEIS é de 2537888 óbitos

# %% [markdown]
# ### Merge de dados de Municípios ao arquivo principal do SIM
#
# Serão utilizados os arquivos:
#
# * população: 'files_clean/censo_pop_clean.csv'
#
# * sim: 'files_clean/dobr_clean.csv'
#
# Como a população está clivada em Município, Idade (previamente, todos abaixo de 75 anos), Sexo e Raça, estes campos serão utilizados de maneira conjunta para realizar o merge.

# %%
# Verificar colunas de população no arquivo censo_pop_clean
censo_pop_mun_4merge_temp = pd.read_parquet('files_clean/censo_pop_mun.parquet')

# mostrar dados gerais da tabela após transformações
tab = censo_pop_mun_4merge_temp
print(f'Registro da tabela : {tab.shape[0]}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 11140
# +----+-------+---------+------+---------------+----------------------------+-------------+---------------+
# |    |   Ano | uf_co   | UF   | mun_cod_sim   | mun_no                     |   pop_total |   pop_under74 |
# |----+-------+---------+------+---------------+----------------------------+-------------+---------------|
# |  0 |  2010 | _11     | RO   | _110001       | Alta Floresta D'Oeste (RO) |       24392 |         23948 |
# |  1 |  2010 | _11     | RO   | _110002       | Ariquemes (RO)             |       90353 |         89037 |
# |  2 |  2010 | _11     | RO   | _110003       | Cabixi (RO)                |        6313 |          6180 |
# |  3 |  2010 | _11     | RO   | _110004       | Cacoal (RO)                |       78574 |         76947 |
# |  4 |  2010 | _11     | RO   | _110005       | Cerejeiras (RO)            |       17029 |         16646 |
# +----+-------+---------+------+---------------+----------------------------+-------------+---------------+

# %%
# Criar um campo string que concatene ANO, CODMUN_SIM, Sexo e cor
censo_pop_mun_4merge_temp01 = censo_pop_mun_4merge_temp.copy()

censo_pop_mun_4merge_temp01['POP_MERGE'] = '_' + censo_pop_mun_4merge_temp01['Ano'].astype(str) + censo_pop_mun_4merge_temp01['mun_cod_sim']


# mostrar dados gerais da tabela após transformações
tab = censo_pop_mun_4merge_temp01
print(f'Registro da tabela : {tab.shape[0]}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 11140
# +----+-------+---------+------+---------------+----------------------------+-------------+---------------+--------------+
# |    |   Ano | uf_co   | UF   | mun_cod_sim   | mun_no                     |   pop_total |   pop_under74 | POP_MERGE    |
# |----+-------+---------+------+---------------+----------------------------+-------------+---------------+--------------|
# |  0 |  2010 | _11     | RO   | _110001       | Alta Floresta D'Oeste (RO) |       24392 |         23948 | _2010_110001 |
# |  1 |  2010 | _11     | RO   | _110002       | Ariquemes (RO)             |       90353 |         89037 | _2010_110002 |
# |  2 |  2010 | _11     | RO   | _110003       | Cabixi (RO)                |        6313 |          6180 | _2010_110003 |
# |  3 |  2010 | _11     | RO   | _110004       | Cacoal (RO)                |       78574 |         76947 | _2010_110004 |
# |  4 |  2010 | _11     | RO   | _110005       | Cerejeiras (RO)            |       17029 |         16646 | _2010_110005 |
# +----+-------+---------+------+---------------+----------------------------+-------------+---------------+--------------+

# %%
# Contar quantos valores são repetidos na coluna 'POP_MERGE'
repeated_values = censo_pop_mun_4merge_temp01['POP_MERGE'].value_counts()

# Filtrar os valores que aparecem mais de uma vez
repeated_more_than_once = repeated_values[repeated_values > 1]

# Exibir os valores repetidos
print(repeated_more_than_once)
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Exibir arquivo dobr_clean
dobr_merged_temp = pd.read_parquet('files_clean/dobr_evit_merged_v2.parquet')

# mostrar dados gerais da tabela após transformações
tab = dobr_merged_temp
print(f'Registro da tabela : {tab.shape[0]}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 2537888
# +----+------------+-------------+-------------+---------------------+
# |    | CAUSABAS   | CODMUNRES   | ANO_OBITO   | classificacao       |
# |----+------------+-------------+-------------+---------------------|
# |  0 | I219       | _292740     | _2019       | Avoidable mortality |
# |  1 | I10        | _355100     | _2019       | Avoidable mortality |
# |  2 | X700       | _500630     | _2019       | Avoidable mortality |
# |  4 | V220       | _500627     | _2019       | Avoidable mortality |
# |  5 | W019       | _500325     | _2019       | Avoidable mortality |
# +----+------------+-------------+-------------+---------------------+

# %%
# Gerar um campo de ano para proxy de 2022 (para ser aplicados aos anos de 19 a 22)
dobr_merged_temp01 = dobr_merged_temp.copy()

dobr_merged_temp01['ANO_PROXY'] = dobr_merged_temp01['ANO_OBITO'].apply(lambda x: '_2010' if x == '_2010' else '_2022')

# Criar um campo string que concatene ANO, CODMUNRES
dobr_merged_temp01['POP_MERGE'] = dobr_merged_temp01['ANO_PROXY'].astype(str) + dobr_merged_temp01['CODMUNRES']

# mostrar dados gerais da tabela após transformações
tab = dobr_merged_temp01
print(f'Registro da tabela : {tab.shape[0]}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registro da tabela : 2537888
# +----+------------+-------------+-------------+---------------------+-------------+--------------+
# |    | CAUSABAS   | CODMUNRES   | ANO_OBITO   | classificacao       | ANO_PROXY   | POP_MERGE    |
# |----+------------+-------------+-------------+---------------------+-------------+--------------|
# |  0 | I219       | _292740     | _2019       | Avoidable mortality | _2022       | _2022_292740 |
# |  1 | I10        | _355100     | _2019       | Avoidable mortality | _2022       | _2022_355100 |
# |  2 | X700       | _500630     | _2019       | Avoidable mortality | _2022       | _2022_500630 |
# |  4 | V220       | _500627     | _2019       | Avoidable mortality | _2022       | _2022_500627 |
# |  5 | W019       | _500325     | _2019       | Avoidable mortality | _2022       | _2022_500325 |
# +----+------------+-------------+-------------+---------------------+-------------+--------------+

# %%
# Verificar operação acima
print(f'Anos de ANO_OBITO {dobr_merged_temp01['ANO_OBITO'].unique()}')
print(f'Anos de ANO_PROXY {dobr_merged_temp01['ANO_PROXY'].unique()}')
# Out:
# Anos de ANO_OBITO ['_2019' '_2020' '_2021' '_2022' '_2010']
# Anos de ANO_PROXY ['_2022' '_2010']

# %% [markdown]
# ########## Este bloco de código a seguir retira o CAUSABAS ##########

# %%
# Agrupar por POP_MERGE e somar os registros, não contabilizando mais por CAUSABAS

col_group= [
            # 'CAUSABAS', 
            'CODMUNRES', 'ANO_OBITO','POP_MERGE']
dobr_merged_temp02 = dobr_merged_temp01.groupby(col_group)['CAUSABAS'].count().reset_index()

# Renomear o campo CAUSABAS para CONTADOR
dobr_merged_temp02.rename(columns={'CAUSABAS':'CONTADOR'}, inplace=True)


# mostrar dados gerais da tabela após transformações
tab = dobr_merged_temp02
print(f'Registros da tabela : {tab.shape[0]}')
print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27923
# Total de óbitos : 2537888
# +----+-------------+-------------+--------------+------------+
# |    | CODMUNRES   | ANO_OBITO   | POP_MERGE    |   CONTADOR |
# |----+-------------+-------------+--------------+------------|
# |  0 | _110000     | _2010       | _2010_110000 |         20 |
# |  1 | _110000     | _2019       | _2022_110000 |          9 |
# |  2 | _110000     | _2020       | _2022_110000 |          7 |
# |  3 | _110000     | _2021       | _2022_110000 |          4 |
# |  4 | _110000     | _2022       | _2022_110000 |          6 |
# +----+-------------+-------------+--------------+------------+

# %%
# Verificação dos nomes das colunas
censo_pop_mun_4merge_temp01.columns
# Out:
# Index(['Ano', 'uf_co', 'UF', 'mun_cod_sim', 'mun_no', 'pop_total',
#        'pop_under74', 'POP_MERGE'],
#       dtype='object')

# %%
# Definir campos de censo_pop para merge
censo_pop_mun_4merge_temp02 = censo_pop_mun_4merge_temp01[['POP_MERGE','pop_under74','UF','mun_no']]

# Realizar o merge dos dataframes
dobr_merged_temp03 = pd.merge(dobr_merged_temp02, censo_pop_mun_4merge_temp02, left_on=['POP_MERGE'], right_on=['POP_MERGE'], how='left')

# mostrar dados gerais da tabela após transformações
tab = dobr_merged_temp03
print(f'Registros da tabela : {tab.shape[0]}')
print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27923
# Total de óbitos : 2537888
# +----+-------------+-------------+--------------+------------+---------------+------+----------+
# |    | CODMUNRES   | ANO_OBITO   | POP_MERGE    |   CONTADOR |   pop_under74 |   UF |   mun_no |
# |----+-------------+-------------+--------------+------------+---------------+------+----------|
# |  0 | _110000     | _2010       | _2010_110000 |         20 |           nan |  nan |      nan |
# |  1 | _110000     | _2019       | _2022_110000 |          9 |           nan |  nan |      nan |
# |  2 | _110000     | _2020       | _2022_110000 |          7 |           nan |  nan |      nan |
# |  3 | _110000     | _2021       | _2022_110000 |          4 |           nan |  nan |      nan |
# |  4 | _110000     | _2022       | _2022_110000 |          6 |           nan |  nan |      nan |
# +----+-------------+-------------+--------------+------------+---------------+------+----------+

# %%
# Filtrar registros onde pop_under74 não é nulo
dobr_merged_temp04 = dobr_merged_temp03.dropna(subset=['pop_under74']).reset_index(drop=True)

# mostrar dados gerais da tabela após transformações
tab = dobr_merged_temp04
print(f'Registros da tabela : {tab.shape[0]}')
print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27817
# Total de óbitos : 2533528
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+
# |    | CODMUNRES   | ANO_OBITO   | POP_MERGE    |   CONTADOR |   pop_under74 | UF   | mun_no                     |
# |----+-------------+-------------+--------------+------------+---------------+------+----------------------------|
# |  0 | _110001     | _2010       | _2010_110001 |         58 |         23948 | RO   | Alta Floresta D'Oeste (RO) |
# |  1 | _110001     | _2019       | _2022_110001 |         67 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# |  2 | _110001     | _2020       | _2022_110001 |         68 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# |  3 | _110001     | _2021       | _2022_110001 |         45 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# |  4 | _110001     | _2022       | _2022_110001 |         64 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+

# %% [markdown]
# ##### Arquivo tratado final

# %%
dobr_merged_temp04.to_parquet('files_clean/dobr_merged_v2.parquet')

# %%
# Resultados

obito_origin = dobr_merged_temp.CAUSABAS.count()
obito_final = dobr_merged_temp04.CONTADOR.sum()
dif = obito_origin - obito_final


print_y(f" O número de óbitos após merge com tabela de CIDs evitáveis era de {obito_origin} óbitos ")
print_y(f" Foram excluídos, por apresentar problemas para carga de informações de município, {dif} óbitos ")
print_y(f" O número de óbitos total após filtro de CID evitáveis e inclusão de população do censo é de {obito_final} óbitos ")


# # Filtrar registros onde pop_under74 é null
# dobr_merged_pop_nulos = dobr_merged_pop[dobr_merged_pop['pop_under74'].isnull()]

# # Exibir os registros filtrados
# dobr_merged_pop_nulos['obito_count'].sum()
# Out:
#  ==>  O número de óbitos após merge com tabela de CIDs evitáveis era de 2537888 óbitos
#  ==>  Foram excluídos, por apresentar problemas para carga de informações de município, 4360 óbitos
#  ==>  O número de óbitos total após filtro de CID evitáveis e inclusão de população do censo é de 2533528 óbitos

# %% [markdown]
# # Etapa 3 - Aplicação de Modelo do HEAT ao Bloco

# %% [markdown]
# O modelo HEAT apresenta um framework bem rígido e objetivo para carga de dados.
#
# O dataset precisa estar organizado com os labels e de acordo com a definição presente no template.
#
# E depois precisa ser validado em planilha excel disponibilizada pela organização.
#
# Ajustes: com a identificação da população por sexo e raça, encontramos 37 registros com população 0. Tivemos que excluir estes registros (incluindo os óbitos) no momento da preparação do dataset do heat em razão do modelo não aceitar estes valores.

# %% [markdown]
# ## Dataset 2 - BR/uf/Mun
#
#
# O primeiro dataset que iremos construir tem as seguintes características:
#
# * setting: Brasil
# * dimension: UF
# * subgroup: município
#
# Estas escolhas implicam em podermos disponibilizar ao usuário do HEAT a possibilidade de ver os municípios (dimensões) de maneira agregada por UF.

# %%
# Define the URL and the destination path
url = "https://srhdpeuwpubsa.blob.core.windows.net/whdh/HIDR/heat_plus_template_validation.xlsm"
destination_path = "downloads_outros/heat_plus_template_validation.xlsm"

# Download the file
response = requests.get(url)
with open(destination_path, 'wb') as file:
    file.write(response.content)

# Note: Enabling macros programmatically is not recommended due to security risks.
# Macros should be enabled manually in Excel settings.

# %%
# Abrir arquivo final de DO após tratamento
heatds_temp = pd.read_parquet('files_clean/dobr_merged_v2.parquet')

# mostrar dados gerais da tabela após transformações
tab = heatds_temp
print(f'Registros da tabela : {tab.shape[0]}')
print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27817
# Total de óbitos : 2533528
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+
# |    | CODMUNRES   | ANO_OBITO   | POP_MERGE    |   CONTADOR |   pop_under74 | UF   | mun_no                     |
# |----+-------------+-------------+--------------+------------+---------------+------+----------------------------|
# |  0 | _110001     | _2010       | _2010_110001 |         58 |         23948 | RO   | Alta Floresta D'Oeste (RO) |
# |  1 | _110001     | _2019       | _2022_110001 |         67 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# |  2 | _110001     | _2020       | _2022_110001 |         68 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# |  3 | _110001     | _2021       | _2022_110001 |         45 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# |  4 | _110001     | _2022       | _2022_110001 |         64 |         20742 | RO   | Alta Floresta D'Oeste (RO) |
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+

# %%
# # Agregar os dados sem CID e gerar colunas de soma de obito_count e pop_under74
# heat_semCID = heat_.groupby(['UF', 'mun_nome', 'CODMUNRES', 'SEXO', 'RACACOR', 'ANO']).agg({
#     'obito_count': 'sum',
#     'pop_under74': 'sum'
# }).reset_index()

# %%
# Gerar o indicador de mortalidade (por 100 mil habitantes) e exibir as primeiras linhas do DataFrame
heatds_temp01 = heatds_temp.copy()

heatds_temp01['mort_ind_mun'] = (heatds_temp01['CONTADOR']/heatds_temp01['pop_under74'])*100000

# mostrar dados gerais da tabela após transformações
tab = heatds_temp01
print(f'Registros da tabela : {tab.shape[0]}')
print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27817
# Total de óbitos : 2533528
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+----------------+
# |    | CODMUNRES   | ANO_OBITO   | POP_MERGE    |   CONTADOR |   pop_under74 | UF   | mun_no                     |   mort_ind_mun |
# |----+-------------+-------------+--------------+------------+---------------+------+----------------------------+----------------|
# |  0 | _110001     | _2010       | _2010_110001 |         58 |         23948 | RO   | Alta Floresta D'Oeste (RO) |        242.191 |
# |  1 | _110001     | _2019       | _2022_110001 |         67 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        323.016 |
# |  2 | _110001     | _2020       | _2022_110001 |         68 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        327.837 |
# |  3 | _110001     | _2021       | _2022_110001 |         45 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        216.951 |
# |  4 | _110001     | _2022       | _2022_110001 |         64 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        308.553 |
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+----------------+

# %%
# Contar e gerar tabela de indicador de mortalidade infinitos [inf]
registros_inf = heatds_temp01[np.isinf(heatds_temp01['mort_ind_mun'])]
inf_count = np.isinf(heatds_temp01['mort_ind_mun']).sum()
nulos_mort_ind_mun = heatds_temp01['mort_ind_mun'].isnull().sum()


# Exibir os registros filtrados
print(f"Número de valores infinitos em mort_ind_mun: {inf_count}")
print(f"Valores nulos em 'mort_ind_mun': {nulos_mort_ind_mun}")



# Exportar registros de indicador de mortalidade infinitos [inf]
# registros_inf.to_csv('exportar/relatorio_reg_mort_ind_inf.csv')
# Out:
# Número de valores infinitos em mort_ind_mun: 0
# Valores nulos em 'mort_ind_mun': 0

# %%
# # Limpar a base de registros de indicador de mortalidade infinitos [inf]
# heat_ds_treat2 = heat_ds_treat.copy()

# # Substituir valores infinitos por NaN
# heat_ds_treat2['mort_ind_mun'].replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# # Rodar se for necessário excluir valores nulos
# heatds_temp02 = heatds_temp01.copy()

# # Excluir registros com NaN na coluna mort_ind_mun
# heatds_temp02.dropna(subset=['mort_ind_mun'], inplace=True)

# # Mudar o nome da coluna mort_ind para mort_ind_mun
# # heat_ds_treat2.rename(columns={'mort_ind':'mort_ind_mun'}, inplace=True)


# # Verificar as primeiras linhas do DataFrame atualizado
# heat_ds_treat1.head()

# %%
# Verificar se existe valor infinito ou negativo na coluna mort_ind_mun
heatds_temp01.describe()
# Out:
#            CONTADOR   pop_under74  mort_ind_mun
# count  27817.000000  2.781700e+04  27817.000000
# mean      91.078405  3.464735e+04    268.207663
# std      510.470539  1.967627e+05     87.673481
# min        1.000000  7.820000e+02     12.640627
# 25%       13.000000  4.978000e+03    211.782434
# 50%       27.000000  1.053200e+04    263.208494
# 75%       62.000000  2.335900e+04    317.028986
# max    28299.000000  1.089676e+07    940.733772

# %% [markdown]
# ##### Agrupar por UF para gerar setting e setting-average
#
# De acordo com o template do HEAT, o setting average: "must be consistent for the same combinantion of: setting, year, source and indicator".
#
# Isto implica que os valores para cada setting (UF) não traz interferência nem da dimensão (município) e nem do subgrupo (sexo-raça-cor).

# %%
# # Agrupar por 'UF', 'ANO', e calcular a média de 'mort_ind'
# dobr_grouped_uf = heat_ds_treat2.groupby(['UF',
#                                              'ANO_OBITO',
#                                             #  'SEXO',
#                                             #  'RACACOR'
#                                              ]).agg({'CONTADOR': 'sum',
#                                                     'pop_under74': 'sum',
#                                                     'mort_ind_mun': 'mean'
#                                                 }).reset_index()
# dobr_grouped_uf.rename(columns={'mort_ind_mun': 'mort_ind_uf',
#                                 'CONTADOR': 'obito_count_uf',
#                                 'pop_under74': 'pop_under74_uf',
#                                 }, inplace=True)


# # Exibir as primeiras linhas do DataFrame resultante
# dobr_grouped_uf.head()

# %%
# dobr_grouped_uf.describe()

# %%
# Salvar arquivo por UF para exportação
# dobr_grouped_uf.to_excel('exportar/dobr_grouped_uf_v2.xlsx', index=False)

# %%
# heat_ds_treat2.columns

# %%
# # Trazer dados por UF (setting e setting_average)

# # Realizar o merge entre heat_ e uf_sett
# heat_treat00 = pd.merge(heat_ds_treat2, dobr_grouped_uf, on=['UF',
#                                                                 'ANO_OBITO',
#                                                                 # 'SEXO',
#                                                                 # 'RACACOR'
#                                                                 ], how='left')

# # Exibir as primeiras linhas do dataframe resultante
# heat_treat00.head()

# %%
# # Teste de aplicação de setting_average (médias por UF)
# filtered_data = heat_treat00[   (heat_treat00['ANO_OBITO'] == '_2022') &
#                                 (heat_treat00['UF'] == 'AC') 
#                                 # & (heat_treat00['SEXO'] == '_1') &
#                                 #(heat_treat00['RACACOR'] == '_4')
#                               ]
# filtered_data.head()

# %%
# heat_treat00.columns

# %%
# heat_treat00.pop_under74_uf.sum()

# %%
# obito_num = heat_treat00.CONTADOR.sum()
# pop_under74 = heat_treat00.pop_under74.sum()

# print(f"\033[33m ==> Número de mortes: {obito_num} \033[0m")
# print(f"\033[33m ==> Número de população abaixo de 75 anos é de {pop_under74} \033[0m")

# %%
# heat_template = row
# heat_template

# %% [markdown]
# ##### Criar colunas do dataset

# %%
# Na média ponderada de mortalidade evitável, pegamos os valores de mortalidade para cada município e dividimos pela população, para conseguir o valor para o Brasil e por ano

# Função para calcular a média ponderada
def weighted_avg(group):
    return np.average(group['mort_ind_mun'], weights=group['pop_under74'])

# Agrupar os dados pelo ano e aplicar a função de média ponderada
weighted_avg_per_year = heatds_temp01.groupby('ANO_OBITO').apply(weighted_avg).reset_index()

# Renomear as colunas para melhor entendimento
weighted_avg_per_year.columns = ['ANO_OBITO', 'set_avg_BR']

# Exibir o resultado
print(weighted_avg_per_year)
# Out:
#   ANO_OBITO  set_avg_BR
# 0     _2010  257.615194
# 1     _2019  258.919766
# 2     _2020  256.542023
# 3     _2021  266.310807
# 4     _2022  274.720874
# /tmp/ipykernel_4975/4059653304.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_avg_per_year = heatds_temp01.groupby('ANO_OBITO').apply(weighted_avg).reset_index()

# %%
# Realizar o merge entre heat_ds_treat2 e grouped_data usando a coluna ANO_OBITO
heatds_temp02 = pd.merge(heatds_temp01, weighted_avg_per_year[['ANO_OBITO', 'set_avg_BR']], on='ANO_OBITO', how='left')

# mostrar dados gerais da tabela após transformações
tab = heatds_temp02
print(f'Registros da tabela : {tab.shape[0]}')
print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27817
# Total de óbitos : 2533528
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+----------------+--------------+
# |    | CODMUNRES   | ANO_OBITO   | POP_MERGE    |   CONTADOR |   pop_under74 | UF   | mun_no                     |   mort_ind_mun |   set_avg_BR |
# |----+-------------+-------------+--------------+------------+---------------+------+----------------------------+----------------+--------------|
# |  0 | _110001     | _2010       | _2010_110001 |         58 |         23948 | RO   | Alta Floresta D'Oeste (RO) |        242.191 |      257.615 |
# |  1 | _110001     | _2019       | _2022_110001 |         67 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        323.016 |      258.92  |
# |  2 | _110001     | _2020       | _2022_110001 |         68 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        327.837 |      256.542 |
# |  3 | _110001     | _2021       | _2022_110001 |         45 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        216.951 |      266.311 |
# |  4 | _110001     | _2022       | _2022_110001 |         64 |         20742 | RO   | Alta Floresta D'Oeste (RO) |        308.553 |      274.721 |
# +----+-------------+-------------+--------------+------------+---------------+------+----------------------------+----------------+--------------+

# %%
# Gerar colunas sem informação ou com informação padronizada
# heat_treat01 = heat_semCID_clean # caso não seja agrupado por UF anteriormente
heatds_temp03 = heatds_temp02.copy() # caso seja agrupado por UF anteriormente

heatds_temp03['setting'] = 'Brasil'
# heat_treat01['setting_average'] = set_avg_BR

heatds_temp03['indicator_abbr'] = 'AVM'
heatds_temp03['indicator_name'] = 'Avoidable mortality (deaths per 100 000 population)'
heatds_temp03['source'] = 'SIM/SUS & Censo/IBGE'
heatds_temp03['favourable_indicator'] = 0
heatds_temp03['indicator_scale'] = 100000
heatds_temp03['ordered_dimension'] = 0
heatds_temp03['subgroup_order'] = 0
heatds_temp03['reference_subgroup'] = 0
heatds_temp03['note'] = ''
heatds_temp03['se'] = ''
heatds_temp03['ci_lb'] = ''
heatds_temp03['ci_ub'] = ''
heatds_temp03['iso3'] = 'BRA'

# Renomear colunas de heat_treat01
heatds_temp03 = heatds_temp03.rename(columns={
    'ANO_OBITO':'date',
    'pop_under74':'population',
    'UF':'dimension',
    'mun_no':'subgroup',
    'mort_ind_mun':'estimate',
    'set_avg_BR':'setting_average',
    # 'mort_ind_uf':'setting_average'
})

# Ajustar coluna de ano
heatds_temp03['date'] = heatds_temp03['date'].str.replace('_','').astype(int)


# mostrar dados gerais da tabela após transformações
tab = heatds_temp03
print(f'Registros da tabela : {tab.shape[0]}')
print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27817
# Total de óbitos : 2533528
# +----+-------------+--------+--------------+------------+--------------+-------------+----------------------------+------------+-------------------+-----------+------------------+-----------------------------------------------------+----------------------+------------------------+-------------------+---------------------+------------------+----------------------+--------+------+---------+---------+--------+
# |    | CODMUNRES   |   date | POP_MERGE    |   CONTADOR |   population | dimension   | subgroup                   |   estimate |   setting_average | setting   | indicator_abbr   | indicator_name                                      | source               |   favourable_indicator |   indicator_scale |   ordered_dimension |   subgroup_order |   reference_subgroup | note   | se   | ci_lb   | ci_ub   | iso3   |
# |----+-------------+--------+--------------+------------+--------------+-------------+----------------------------+------------+-------------------+-----------+------------------+-----------------------------------------------------+----------------------+------------------------+-------------------+---------------------+------------------+----------------------+--------+------+---------+---------+--------|
# |  0 | _110001     |   2010 | _2010_110001 |         58 |        23948 | RO          | Alta Floresta D'Oeste (RO) |    242.191 |           257.615 | Brasil    | AVM              | Avoidable mortality (deaths per 100 000 population) | SIM/SUS & Censo/IBGE |                      0 |            100000 |                   0 |                0 |                    0 |        |      |         |         | BRA    |
# |  1 | _110001     |   2019 | _2022_110001 |         67 |        20742 | RO          | Alta Floresta D'Oeste (RO) |    323.016 |           258.92  | Brasil    | AVM              | Avoidable mortality (deaths per 100 000 population) | SIM/SUS & Censo/IBGE |                      0 |            100000 |                   0 |                0 |                    0 |        |      |         |         | BRA    |
# |  2 | _110001     |   2020 | _2022_110001 |         68 |        20742 | RO          | Alta Floresta D'Oeste (RO) |    327.837 |           256.542 | Brasil    | AVM              | Avoidable mortality (deaths per 100 000 population) | SIM/SUS & Censo/IBGE |                      0 |            100000 |                   0 |                0 |                    0 |        |      |         |         | BRA    |
# |  3 | _110001     |   2021 | _2022_110001 |         45 |        20742 | RO          | Alta Floresta D'Oeste (RO) |    216.951 |           266.311 | Brasil    | AVM              | Avoidable mortality (deaths per 100 000 population) | SIM/SUS & Censo/IBGE |                      0 |            100000 |                   0 |                0 |                    0 |        |      |         |         | BRA    |
# |  4 | _110001     |   2022 | _2022_110001 |         64 |        20742 | RO          | Alta Floresta D'Oeste (RO) |    308.553 |           274.721 | Brasil    | AVM              | Avoidable mortality (deaths per 100 000 population) | SIM/SUS & Censo/IBGE |                      0 |            100000 |                   0 |                0 |                    0 |        |      |         |         | BRA    |
# +----+-------------+--------+--------------+------------+--------------+-------------+----------------------------+------------+-------------------+-----------+------------------+-----------------------------------------------------+----------------------+------------------------+-------------------+---------------------+------------------+----------------------+--------+------+---------+---------+--------+

# %%
# # Trazer labels para sexo e raçacor
# heat_treat02 = heat_treat01.copy()

# heat_treat02['SEXO'] = heat_treat02['SEXO'].map({
#                                             '_1':'Homens',
#                                             '_2':'Mulheres'
#                                             })
# heat_treat02['RACACOR'] = heat_treat02['RACACOR'].map({
#                                             '_1':'Branca',
#                                             '_2':'Preta',
#                                             '_3':'Amarela',
#                                             '_4':'Parda',
#                                             '_5':'Indígena',
#                                             '_9':'Sem declaração'
#                                             })

# heat_treat02['subgroup'] = heat_treat02['SEXO'] + ' - raça/cor '  +  heat_treat02['RACACOR']

# %%
# heat_treat02['subgroup'].unique()

# %%
# heat_treat02.columns

# %%
# Define the order of columns
column_order = [
    'setting',
    'date',
    'source',
    'indicator_abbr',
    'indicator_name',
    'dimension',
    'subgroup',
    'estimate',
    'se',
    'ci_lb',
    'ci_ub',
    'population',
    'note',
    'setting_average',
    'iso3',
    'favourable_indicator',
    'indicator_scale',
    'ordered_dimension',
    'subgroup_order',
    'reference_subgroup'
    ]  


# Reorder the columns in the DataFrame
heatds_temp04 = heatds_temp03[column_order]

# %%
# Transformar estimate e setting_average em int
heatds_temp05 = heatds_temp04.copy()

heatds_temp05['estimate'] = heatds_temp05['estimate'].astype(int)
heatds_temp05['setting_average'] = heatds_temp05['setting_average'].astype(int)

# mostrar dados gerais da tabela após transformações
tab = heatds_temp05
print(f'Registros da tabela : {tab.shape[0]}')
# print(f'Total de óbitos : {tab.CONTADOR.sum()}')
print(tabulate(tab.head(), headers='keys', tablefmt='psql'))
# Out:
# Registros da tabela : 27817
# +----+-----------+--------+----------------------+------------------+-----------------------------------------------------+-------------+----------------------------+------------+------+---------+---------+--------------+--------+-------------------+--------+------------------------+-------------------+---------------------+------------------+----------------------+
# |    | setting   |   date | source               | indicator_abbr   | indicator_name                                      | dimension   | subgroup                   |   estimate | se   | ci_lb   | ci_ub   |   population | note   |   setting_average | iso3   |   favourable_indicator |   indicator_scale |   ordered_dimension |   subgroup_order |   reference_subgroup |
# |----+-----------+--------+----------------------+------------------+-----------------------------------------------------+-------------+----------------------------+------------+------+---------+---------+--------------+--------+-------------------+--------+------------------------+-------------------+---------------------+------------------+----------------------|
# |  0 | Brasil    |   2010 | SIM/SUS & Censo/IBGE | AVM              | Avoidable mortality (deaths per 100 000 population) | RO          | Alta Floresta D'Oeste (RO) |        242 |      |         |         |        23948 |        |               257 | BRA    |                      0 |            100000 |                   0 |                0 |                    0 |
# |  1 | Brasil    |   2019 | SIM/SUS & Censo/IBGE | AVM              | Avoidable mortality (deaths per 100 000 population) | RO          | Alta Floresta D'Oeste (RO) |        323 |      |         |         |        20742 |        |               258 | BRA    |                      0 |            100000 |                   0 |                0 |                    0 |
# |  2 | Brasil    |   2020 | SIM/SUS & Censo/IBGE | AVM              | Avoidable mortality (deaths per 100 000 population) | RO          | Alta Floresta D'Oeste (RO) |        327 |      |         |         |        20742 |        |               256 | BRA    |                      0 |            100000 |                   0 |                0 |                    0 |
# |  3 | Brasil    |   2021 | SIM/SUS & Censo/IBGE | AVM              | Avoidable mortality (deaths per 100 000 population) | RO          | Alta Floresta D'Oeste (RO) |        216 |      |         |         |        20742 |        |               266 | BRA    |                      0 |            100000 |                   0 |                0 |                    0 |
# |  4 | Brasil    |   2022 | SIM/SUS & Censo/IBGE | AVM              | Avoidable mortality (deaths per 100 000 population) | RO          | Alta Floresta D'Oeste (RO) |        308 |      |         |         |        20742 |        |               274 | BRA    |                      0 |            100000 |                   0 |                0 |                    0 |
# +----+-----------+--------+----------------------+------------------+-----------------------------------------------------+-------------+----------------------------+------------+------+---------+---------+--------------+--------+-------------------+--------+------------------------+-------------------+---------------------+------------------+----------------------+

# %%
### Arquivo pronto para exportação
heatds_temp05.to_excel('exportar/ds_4val_v2.xlsx', index=False)

# %%
# Gerar arquivo dataset diretamente no arquivo de validação do HEAT

# Carregar o arquivo original
workbook = openpyxl.load_workbook('downloads_outros/heat_plus_template_validation.xlsm', keep_vba=True)

# Apagar a aba 'template'
if 'template' in workbook.sheetnames:
    del workbook['template']

# Carregar o arquivo que será copiado como nova aba
workbook_to_copy = openpyxl.load_workbook('exportar/ds_4val_v2.xlsx')
sheet_to_copy = workbook_to_copy.active

# Copiar a aba para o workbook original
new_sheet = workbook.create_sheet('template')

for row in sheet_to_copy.iter_rows(values_only=True):
    new_sheet.append(row)

# Salvar o arquivo com o novo nome
workbook.save('exportar/heat_plus_template_ds_4val_v2.xlsm')

# %% [markdown]
# # Etapa 4 - Reunião de alinhamento - ajustes

# %% [markdown]
# # Etapa 5 - Preparação para publicação de resultados

# %% [markdown]
# # EXCLUIR TUDO A PARTIR DAQUI

# %%
teste_fail = pd.read_parquet('files_clean/dobr_merged_clean.parquet')
teste_fail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27916 entries, 3 to 31224
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CODMUNRES    27916 non-null  object
#  1   SEXO         27916 non-null  object
#  2   RACACOR      27916 non-null  object
#  3   ANO          27916 non-null  int64
#  4   POP_MERGE    27916 non-null  object
#  5   obito_count  27916 non-null  int64
#  6   pop_under74  27916 non-null  float64
#  7   UF           27916 non-null  object
#  8   mun_nome     27916 non-null  object
#  9   mort_ind     27916 non-null  float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 2.3+ MB

# %%
teste_fail = pd.read_excel('exportar/ds_4val.xlsx')
teste_fail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27879 entries, 0 to 27878
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   setting               27879 non-null  object
#  1   date                  27879 non-null  int64
#  2   source                27879 non-null  object
#  3   indicator_abbr        27879 non-null  object
#  4   indicator_name        27879 non-null  object
#  5   dimension             27879 non-null  object
#  6   subgroup              27879 non-null  object
#  7   estimate              27879 non-null  int64
#  8   se                    0 non-null      float64
#  9   ci_lb                 0 non-null      float64
#  10  ci_ub                 0 non-null      float64
#  11  population            27879 non-null  int64
#  12  note                  0 non-null      float64
#  13  setting_average       27879 non-null  int64
#  14  iso3                  0 non-null      float64
#  15  favourable_indicator  27879 non-null  int64
#  16  indicator_scale       27879 non-null  int64
#  17  ordered_dimension     27879 non-null  int64
#  18  subgroup_order        27879 non-null  int64
#  19  reference_subgroup    27879 non-null  int64
# dtypes: float64(5), int64(9), object(6)
# memory usage: 4.3+ MB

# %%
teste_fail = dobr_merged_pop

# %%
# teste_fail0 = teste_fail.loc[teste_fail['Ano'] == 2022]
teste_fail2 = teste_fail.groupby('setting')['population'].sum().reset_index()
# teste_fail2['pop_under74'] = teste_fail2['pop_under74'].astype(int)
teste_fail2.head(10)
# Out:
#   setting  population
# 0      AC      779569
# 1      AL     2948673
# 2      AM     3770310
# 3      AP      702835
# 4      BA    13253895
# 5      CE     8277438
# 6      DF     2724847
# 7      ES     3649270
# 8      GO     6709152
# 9      MA     6400579

# %%
# teste_fail0 = teste_fail.loc[teste_fail['Ano'] == 2022]
teste_fail2 = teste_fail.groupby('UF')['pop_under74'].sum().reset_index()
teste_fail2['pop_under74'] = teste_fail2['pop_under74'].astype(int)
teste_fail2.head(10)
# Out:
#    UF  pop_under74
# 0  AC       779569
# 1  AL      2948673
# 2  AM      3770310
# 3  AP       702835
# 4  BA     13253895
# 5  CE      8277438
# 6  DF      2724847
# 7  ES      3649270
# 8  GO      6709152
# 9  MA      6400579

# %%
# Calcular a taxa de mortalidade
dobr_merged_clean['mort_ind'] = (dobr_merged_clean['obito_count'] / dobr_merged_clean['pop_under74']) * 100000

# Verificar as primeiras linhas do DataFrame atualizado
dobr_merged_clean.head()

# %%
teste_uf_ = censo_pop_clean03[censo_pop_clean03['Nível'] == 'MU']
teste_uf_.head()
# Out:
#      Ano Nível     Cód.              unidade_no  pop_total  pop_under74  UF  \
# 27  2010    MU  1100015  Alta Floresta D'Oeste       24392        23948  RO
# 28  2010    MU  1100023              Ariquemes       90353        89037  RO
# 29  2010    MU  1100031                 Cabixi        6313         6180  RO
# 30  2010    MU  1100049                 Cacoal       78574        76947  RO
# 31  2010    MU  1100056             Cerejeiras       17029        16646  RO
#
#    uf_co
# 27   _11
# 28   _11
# 29   _11
# 30   _11
# 31   _11

# %%
teste_all_idade = dobr_df.copy()

# %%
# campo idade_num formado pelos 2 últimos caracteres de IDADE
teste_all_idade['IDADE_DO_NUM'] = teste_all_idade['IDADE'].str[-2:]

# campo idade_ref formado pelo 1º caractere de IDADE
teste_all_idade['IDADE_DO_REF'] = teste_all_idade['IDADE'].str[0]

# %%
teste_all_idade['IDADE_DO_NUM'] = teste_all_idade['IDADE_DO_NUM'].astype(int)
teste_all_idade['IDADE_DO_REF'] = teste_all_idade['IDADE_DO_REF'].astype(int)

# %%
teste_all_idade['IDADE_DO_REF'].unique()
# Out:
# array([4, 9, 5, 3, 1, 2, 0])

# %%
teste_all_idade['IDADE_DO_NUM'].unique()

# %%
# Fazer uma slice de 30 registros da tabela dobr_df de maneira aleatória
teste_idade = dobr_df[['DTNASC', 'DTOBITO','IDADE']].sample(30)

teste_idade.head()
# Out:
#            DTNASC   DTOBITO IDADE
# 505467   26071963  03122022   459
# 533859   07031941  28012022   480
# 220070   31031954  28052022   468
# 1137067  22061934  30072022   488
# 19522    09011974  25062022   448

# %%
# 20 registros aleatórios da tabela dobr_df com IDADE_DO_REF == 0
idade_ref0 = teste_all_idade[teste_all_idade['IDADE_DO_REF'] == 9].sample(20)
teste_idade = idade_ref0[['DTNASC', 'DTOBITO','IDADE']]
teste_idade.head(20)
# Out:
#            DTNASC   DTOBITO IDADE
# 519                31052022   999
# 1285329            17092022   999
# 1346726            06092022   999
# 643331             13062022   999
# 916924             10012022   999
# 351921             14122022   999
# 1410064            19102022   999
# 1093449            03112022   999
# 292407             18102022   999
# 13167              26012022   999
# 341982             27072022   999
# 1449676            09082022   999
# 22171              16062022   999
# 1447209            01082022   999
# 319337             24082022   999
# 701212             15112022   999
# 1247538            13112022   999
# 218175             07052022   999
# 158138             17062022   999
# 166112             30012022   999

# %%
idade_ref9 = teste_all_idade[teste_all_idade['IDADE_DO_REF'] == 9].size
idade_ref9
# Out:
# 210330

# %%
teste_idade = idade_ref0[['DTNASC', 'DTOBITO','IDADE']]

# campo idade_num formado pelos 2 últimos caracteres de IDADE
teste_idade['IDADE_DO_NUM'] = teste_idade['IDADE'].str[-2:]

# campo idade_ref formado pelo 1º caractere de IDADE
teste_idade['IDADE_DO_REF'] = teste_idade['IDADE'].str[0]

# campo ano_nasc formado pelos 4 últimos caracteres de DTNASC, como número
teste_idade['ANO_NASC'] = teste_idade['DTNASC'].str[-4:]

# campo ano_obito formado pelos 4 últimos caracteres de DTOBITO, como número
teste_idade['ANO_OBITO'] = teste_idade['DTOBITO'].str[-4:]

# mudar formato para número os campos ANO_NASC e ANO_OBITO e IDADE_NUM
teste_idade['IDADE_DO_NUM'] = teste_idade['IDADE_DO_NUM'].astype(int)
teste_idade['ANO_NASC'] = teste_idade['ANO_NASC'].astype(int)
teste_idade['ANO_OBITO'] = teste_idade['ANO_OBITO'].astype(int)

# campo idade_obito formado pela diferença entre ANO_OBITO e ANO_NASC
teste_idade['IDADE_OBITO'] = teste_idade['ANO_OBITO'] - teste_idade['ANO_NASC']

# registrar a diferença entre IDADE_DO_NUM e IDADE_OBITO
teste_idade['DIFERENCA_IDADE_DO'] = teste_idade['IDADE_DO_NUM'] - teste_idade['IDADE_OBITO']

teste_idade.head(20)
# Out:
# /tmp/ipykernel_58425/4162421664.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['IDADE_DO_NUM'] = teste_idade['IDADE'].str[-2:]
# /tmp/ipykernel_58425/4162421664.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['IDADE_DO_REF'] = teste_idade['IDADE'].str[0]
# /tmp/ipykernel_58425/4162421664.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['ANO_NASC'] = teste_idade['DTNASC'].str[-4:]
# /tmp/ipykernel_58425/4162421664.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['ANO_OBITO'] = teste_idade['DTOBITO'].str[-4:]
# /tmp/ipykernel_58425/4162421664.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['IDADE_DO_NUM'] = teste_idade['IDADE_DO_NUM'].astype(int)
# /tmp/ipykernel_58425/4162421664.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['ANO_NASC'] = teste_idade['ANO_NASC'].astype(int)
# /tmp/ipykernel_58425/4162421664.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['ANO_OBITO'] = teste_idade['ANO_OBITO'].astype(int)
# /tmp/ipykernel_58425/4162421664.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['IDADE_OBITO'] = teste_idade['ANO_OBITO'] - teste_idade['ANO_NASC']
# /tmp/ipykernel_58425/4162421664.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste_idade['DIFERENCA_IDADE_DO'] = teste_idade['IDADE_DO_NUM'] - teste_idade['IDADE_OBITO']
#            DTNASC   DTOBITO IDADE  IDADE_DO_NUM IDADE_DO_REF  ANO_NASC  \
# 667727   03062022  03062022   023            23            0      2022
# 191219   08092022  08092022   042            42            0      2022
# 319242   09082022  09082022   020            20            0      2022
# 352952   03072022  03072022   035            35            0      2022
# 469040   16062022  16062022   040            40            0      2022
# 1080834  10072022  10072022   022            22            0      2022
# 1264696  19112022  19112022   001             1            0      2022
# 485259   01122022  01122022   020            20            0      2022
# 1281582  28092022  28092022   005             5            0      2022
# 42111    20102022  20102022   010            10            0      2022
# 1502206  24022022  24022022   015            15            0      2022
# 1277894  06082022  06082022   043            43            0      2022
# 1321162  17042022  17042022   020            20            0      2022
# 1427215  30082022  30082022   016            16            0      2022
# 840043   10112022  10112022   020            20            0      2022
# 545021   20052022  20052022   045            45            0      2022
# 555662   13012022  13012022   020            20            0      2022
# 959483   22082022  22082022   007             7            0      2022
# 459732   27052022  27052022   045            45            0      2022
# 1254063  25122022  25122022   022            22            0      2022
#
#          ANO_OBITO  IDADE_OBITO  DIFERENCA_IDADE_DO
# 667727        2022            0                  23
# 191219        2022            0                  42
# 319242        2022            0                  20
# 352952        2022            0                  35
# 469040        2022            0                  40
# 1080834       2022            0                  22
# 1264696       2022            0                   1
# 485259        2022            0                  20
# 1281582       2022            0                   5
# 42111         2022            0                  10
# 1502206       2022            0                  15
# 1277894       2022            0                  43
# 1321162       2022            0                  20
# 1427215       2022            0                  16
# 840043        2022            0                  20
# 545021        2022            0                  45
# 555662        2022            0                  20
# 959483        2022            0                   7
# 459732        2022            0                  45
# 1254063       2022            0                  22

# %%
# campo idade_num formado pelos 2 últimos caracteres de IDADE
teste_idade['IDADE_DO_NUM'] = teste_idade['IDADE'].str[-2:]

# campo idade_ref formado pelo 1º caractere de IDADE
teste_idade['IDADE_DO_REF'] = teste_idade['IDADE'].str[0]

# campo ano_nasc formado pelos 4 últimos caracteres de DTNASC, como número
teste_idade['ANO_NASC'] = teste_idade['DTNASC'].str[-4:]

# campo ano_obito formado pelos 4 últimos caracteres de DTOBITO, como número
teste_idade['ANO_OBITO'] = teste_idade['DTOBITO'].str[-4:]

# mudar formato para número os campos ANO_NASC e ANO_OBITO e IDADE_NUM
teste_idade['IDADE_DO_NUM'] = teste_idade['IDADE_DO_NUM'].astype(int)
teste_idade['ANO_NASC'] = teste_idade['ANO_NASC'].astype(int)
teste_idade['ANO_OBITO'] = teste_idade['ANO_OBITO'].astype(int)

# campo idade_obito formado pela diferença entre ANO_OBITO e ANO_NASC
teste_idade['IDADE_OBITO'] = teste_idade['ANO_OBITO'] - teste_idade['ANO_NASC']

# registrar a diferença entre IDADE_DO_NUM e IDADE_OBITO
teste_idade['DIFERENCA_IDADE_DO'] = teste_idade['IDADE_DO_NUM'] - teste_idade['IDADE_OBITO']

teste_idade.head(30)
# Out:
#            DTNASC   DTOBITO IDADE  IDADE_DO_NUM IDADE_DO_REF  ANO_NASC  \
# 505467   26071963  03122022   459            59            4      1963
# 533859   07031941  28012022   480            80            4      1941
# 220070   31031954  28052022   468            68            4      1954
# 1137067  22061934  30072022   488            88            4      1934
# 19522    09011974  25062022   448            48            4      1974
# 1082153  22031928  19102022   494            94            4      1928
# 667317   17051969  10052022   452            52            4      1969
# 985667   07071932  07062022   489            89            4      1932
# 526522   19101960  13052022   461            61            4      1960
# 1201760  13032003  05022022   418            18            4      2003
# 426180   06121923  15012022   498            98            4      1923
# 938915   27041974  07022022   447            47            4      1974
# 147771   21041946  16052022   476            76            4      1946
# 287393   06101945  11102022   477            77            4      1945
# 874995   19041938  11082022   484            84            4      1938
# 738499   06011946  27022022   476            76            4      1946
# 161904   28081936  29062022   485            85            4      1936
# 291829   06101987  07102022   435            35            4      1987
# 1063438  25021972  26082022   450            50            4      1972
# 127023   11042010  21022022   411            11            4      2010
# 588950   27021938  05012022   483            83            4      1938
# 146501   20061966  03022022   455            55            4      1966
# 578138   21112001  24042022   420            20            4      2001
# 361301   02041956  05012022   465            65            4      1956
# 1444623  28051942  06072022   480            80            4      1942
# 715132   06032003  11122022   419            19            4      2003
# 1038390  11122001  12072022   420            20            4      2001
# 1443839  28101926  12072022   495            95            4      1926
# 1523364  14041955  05042022   466            66            4      1955
# 235657   25031978  05012022   443            43            4      1978
#
#          ANO_OBITO  IDADE_OBITO  DIFERENCA_IDADE_DO
# 505467        2022           59                   0
# 533859        2022           81                  -1
# 220070        2022           68                   0
# 1137067       2022           88                   0
# 19522         2022           48                   0
# 1082153       2022           94                   0
# 667317        2022           53                  -1
# 985667        2022           90                  -1
# 526522        2022           62                  -1
# 1201760       2022           19                  -1
# 426180        2022           99                  -1
# 938915        2022           48                  -1
# 147771        2022           76                   0
# 287393        2022           77                   0
# 874995        2022           84                   0
# 738499        2022           76                   0
# 161904        2022           86                  -1
# 291829        2022           35                   0
# 1063438       2022           50                   0
# 127023        2022           12                  -1
# 588950        2022           84                  -1
# 146501        2022           56                  -1
# 578138        2022           21                  -1
# 361301        2022           66                  -1
# 1444623       2022           80                   0
# 715132        2022           19                   0
# 1038390       2022           21                  -1
# 1443839       2022           96                  -1
# 1523364       2022           67                  -1
# 235657        2022           44                  -1

# %%
# Identificar municípios com problemas para merge

# registros com mun_no nulos
mun_nulos = dobr_merged_pop[dobr_merged_pop['mun_no'].isnull()]
mun_nulos.head(30)
# Out:
#      CODMUNRES ANO_OBITO     POP_MERGE  CONTADOR  pop_under74   UF mun_no
# 0      _110000     _2022  _2022_110000         6          NaN  NaN    NaN
# 53     _120000     _2022  _2022_120000         3          NaN  NaN    NaN
# 76     _130000     _2022  _2022_130000        26          NaN  NaN    NaN
# 154    _150000     _2022  _2022_150000        15          NaN  NaN    NaN
# 454    _210000     _2022  _2022_210000         5          NaN  NaN    NaN
# 672    _220000     _2022  _2022_220000         4          NaN  NaN    NaN
# 1081   _240000     _2022  _2022_240000         3          NaN  NaN    NaN
# 1249   _250000     _2022  _2022_250000        16          NaN  NaN    NaN
# 1473   _260000     _2022  _2022_260000        50          NaN  NaN    NaN
# 1659   _270000     _2022  _2022_270000         1          NaN  NaN    NaN
# 1762   _280000     _2022  _2022_280000         1          NaN  NaN    NaN
# 1838   _290000     _2022  _2022_290000        73          NaN  NaN    NaN
# 2256   _310000     _2022  _2022_310000        88          NaN  NaN    NaN
# 3110   _320000     _2022  _2022_320000        23          NaN  NaN    NaN
# 3189   _330000     _2022  _2022_330000       188          NaN  NaN    NaN
# 3282   _350000     _2022  _2022_350000       179          NaN  NaN    NaN
# 3928   _410000     _2022  _2022_410000        41          NaN  NaN    NaN
# 4328   _420000     _2022  _2022_420000        10          NaN  NaN    NaN
# 4624   _430000     _2022  _2022_430000         2          NaN  NaN    NaN
# 5122   _500000     _2022  _2022_500000         1          NaN  NaN    NaN
# 5202   _510000     _2022  _2022_510000         2          NaN  NaN    NaN
# 5343   _520000     _2022  _2022_520000        26          NaN  NaN    NaN

# %%
mun_nulos.size
# Out:
# 154

# %%
# Calcular a taxa de mortalidade
dobr_merged_final['mort_ind'] = (dobr_merged_final['obito_count'] / dobr_merged_final['pop_under74']) * 100000

# Verificar as primeiras linhas do DataFrame atualizado
dobr_merged_final.head()
